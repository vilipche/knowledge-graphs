# %%
# import libraries
from rdflib import Graph,Literal,RDF,URIRef
from rdflib.namespace import FOAF,XSD,RDFS
from rdflib import Namespace
import pandas as pd
import random

# %%
g = Graph()

# %%
KG_SDM = Namespace("http://kg_sdm.org/")
g.bind("kg_sdm",KG_SDM) # the uri will be repliced

# %% [markdown]
# ## Adding person sublasses

# %%
# Author subclass Person
# Author: school
# Person: name
# Create a table of names and schools which will be later sliced to Author, Editor etc.

# %%
people_names = pd.read_csv('data_kg_sdm/authors.csv')
people_names = people_names.drop(columns='ID')
people_names.rename(columns = {'name':'person_name'}, inplace=True)

# %%
people_names
# Out:
#                  person_name
# 0                  Gautam A.
# 1              Crandall J.W.
# 2              Goodrich M.A.
# 3     de Moura Oliveira P.B.
# 4             Hedengren J.D.
# ...                      ...
# 2167              Allen B.L.
# 2168             Anapalli S.
# 2169          Blackshaw R.E.
# 2170               Lyon D.J.
# 2171              Machado S.
#
# [2172 rows x 1 columns]

# %%
schools = pd.read_csv('data_kg_sdm/schools.csv')
schools = schools.drop(columns='ID')
schools.rename(columns = {'name':'school_name'}, inplace=True)

# %%
academics = people_names.loc[:schools.size-1]
academics['school_name'] = schools
# Out:
# <ipython-input-63-454e3bb8a4db>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   academics['school_name'] = schools

# %%
academics
# Out:
#                  person_name  \
# 0                  Gautam A.
# 1              Crandall J.W.
# 2              Goodrich M.A.
# 3     de Moura Oliveira P.B.
# 4             Hedengren J.D.
# ...                      ...
# 1456             Hedges D.M.
# 1457         Steffensen S.C.
# 1458                Puleo C.
# 1459             Galligan C.
# 1460                 Ashe J.
#
#                                             school_name
# 0     Computer Science Department, Brigham Young Uni...
# 1     INESC-TEC Technology and Science, Campus da FE...
# 2      Department of Engineering, University of Trás...
# 3      Department of Chemical Engineering, Brigham Y...
# 4     Task Committee Secretary and Lead Engineer, Op...
# ...                                                 ...
# 1456   United States Department of Agriculture-Agric...
# 1457   United States Department of Agriculture-Agric...
# 1458   Agriculture and Agri-Food Canada, Lethbridge,...
# 1459   Department of Crop and Soil Sciences, Washing...
# 1460   Columbia Basin Agricultural Research Center, ...
#
# [1461 rows x 2 columns]

# %%
# We suppose 60% are Authors, 20% Reviewsrs, 10% Chair or Editor

# %%
total = len(academics)
nb_auth = int(total * 0.6)
nb_rev = int(total * 0.2)
nb_chair_editor = int(total * 0.1)

# %%
authors = academics.loc[:nb_auth]
reviewers = academics.loc[nb_auth : nb_auth + nb_rev]
chair = academics.loc[nb_auth + nb_rev : nb_auth + nb_rev + nb_chair_editor ]
editor = academics.loc[ nb_auth + nb_rev + nb_chair_editor :nb_auth + nb_rev + nb_chair_editor + nb_chair_editor]

# %%
editor.head()
# Out:
#        person_name                                        school_name
# 1314  Choudhury D.   Department of Architecture, Building and Plan...
# 1315     Chanda A.   ISISE, University of Minho, Department of Civ...
# 1316     Ruchti T.  Utah State University, ENGR 419J, Logan, UT  8...
# 1317   Upchurch W.   Naval Undersea Warfare Center, Newport, RI, U...
# 1318      Lee J.H.   Pennsylvania State University, State College,...

# %%
import string

# %%
def URLparse(url:str):
    url=url.replace("\'","_").replace("\"","_")
    for i in string.punctuation:
        url = url.replace(i,"_")
    url = url.replace(" ","_")
    return url

# %%
person_type_list = [authors,reviewers,chair,editor]
person_sub_type_ls = ["Author","Reviewers","Chair","Editor"]

# %%
Person = URIRef("http://kg_sdm.org/Person")

for i,person_tp in enumerate(person_type_list):
    preson_sub_type = URIRef(f"http://kg_sdm.org/{person_sub_type_ls[i]}")
    
    for name, school in zip(person_tp['person_name'], person_tp['school_name']):
    #   editor_node = URIRef(f"http://kg_sdm.org/{URLparse(name)}")
        parsed_name = URLparse(name)
        person_node = URIRef(f"http://kg_sdm.org/{parsed_name}")
        name_lit = Literal(str(name))
        school_lit = Literal(str(school))

        # add subclass type
        g.add((person_node, RDF.type, preson_sub_type))
        # add school
        g.add((person_node, KG_SDM.school, school_lit))
        # add name of person
        g.add((person_node, FOAF.name, name_lit))

# %% [markdown]
# ## Adding paper submitted in Venue

# %%
articles = pd.read_csv('data_kg_sdm/articles.csv')
articles = articles.loc[:len(authors)-1]
articles
# Out:
#       ID                                              title     volume  \
# 0      1  Self-assessment of Proficiency of Intelligent ...  1210 AISC
# 1      2  Bridging theory to practice: Feedforward and c...   695 LNEE
# 2      3  Development of sediment management guidelines ...        146
# 3      4  Structural design space exploration using prin...         20
# 4      5  Religion-focused dating apps: A Q methodology ...         55
# ..   ...                                                ...        ...
# 872  873  Highly compressible origami bellows for microg...        NaN
# 873  874  Interspecific hybridization for upland cotton ...        NaN
# 874  875  Thermophysical properties of thin fibers via p...        112
# 875  876  Formability of magnesium alloy AZ31B from room...    Part F8
# 876  877  A summary of data-aided equalizer experiments ...        NaN
#
#                                           DOI
# 0                10.1007/978-3-030-51758-8_15
# 1                 10.1007/978-3-030-58653-9_3
# 2          10.1061/(ASCE)HY.1943-7900.0001822
# 3                           10.1115/1.4047428
# 4                  10.1016/j.tele.2020.101448
# ..                                        ...
# 872                       10.2514/6.2017-5341
# 873                     10.1201/9781315369259
# 874  10.1016/j.ijheatmasstransfer.2017.05.046
# 875              10.1007/978-3-319-52392-7_91
# 876                                       NaN
#
# [877 rows x 4 columns]

# %%
publications = pd.read_csv('data_kg_sdm/publications.csv')
publications
# Out:
#       ID                                               name              Type
# 0      1      Advances in Intelligent Systems and Computing  Conference Paper
# 1      2            Lecture Notes in Electrical Engineering  Conference Paper
# 2      3                   Journal of Hydraulic Engineering           Journal
# 3      4  Journal of Computing and Information Science i...           Journal
# 4      5                         Telematics and Informatics  Conference Paper
# ..   ...                                                ...               ...
# 399  400                          CAD Computer Aided Design  Conference Paper
# 400  401  International Symposium on Advances in Computa...  Conference Paper
# 401  402  AIAA SPACE and Astronautics Forum and Expositi...  Conference Paper
# 402  403    IEEE Transactions on Control of Network Systems  Conference Paper
# 403  404                 Innovations in Dryland Agriculture  Conference Paper
#
# [404 rows x 3 columns]

# %%
# import random
# article_publisher_link = pd.read_csv('data_kg_sdm/article_published_by.csv')
# random.seed(0)
# publisher_ID = [random.randint(1, 404) for i in range(len(article_publisher_link))]
# publisher_ID
# article_publisher_link['publisher_ID'] = publisher_ID
# # article_publisher_link.drop(columns=article_publisher_link.columns[0], axis=1, inplace=True)
# article_publisher_link.to_csv('data_kg_sdm/article_published_by.csv',index=False)

# %%
article_publisher_link = pd.read_csv('data_kg_sdm/article_published_by.csv')
article_publisher_link
# Out:
#      article_ID  publisher_ID  year
# 0             1           198  2020
# 1             2           389  2020
# 2             3           216  2020
# 3             4            21  2018
# 4             5           133  2018
# ..          ...           ...   ...
# 875         876           360  2017
# 876         877           229  2015
# 877         878           205  2015
# 878         879            95  2016
# 879         880           394  2016
#
# [880 rows x 3 columns]

# %%
article_pub = pd.merge(articles, article_publisher_link, left_on='ID', right_on='article_ID')
articles_publishedin = pd.merge(article_pub, publications, left_on='publisher_ID', right_on='ID',how='left')
articles_publishedin
# Out:
#      ID_x                                              title     volume  \
# 0       1  Self-assessment of Proficiency of Intelligent ...  1210 AISC
# 1       2  Bridging theory to practice: Feedforward and c...   695 LNEE
# 2       3  Development of sediment management guidelines ...        146
# 3       4  Structural design space exploration using prin...         20
# 4       5  Religion-focused dating apps: A Q methodology ...         55
# ..    ...                                                ...        ...
# 872   873  Highly compressible origami bellows for microg...        NaN
# 873   874  Interspecific hybridization for upland cotton ...        NaN
# 874   875  Thermophysical properties of thin fibers via p...        112
# 875   876  Formability of magnesium alloy AZ31B from room...    Part F8
# 876   877  A summary of data-aided equalizer experiments ...        NaN
#
#                                           DOI  article_ID  publisher_ID  year  \
# 0                10.1007/978-3-030-51758-8_15           1           198  2020
# 1                 10.1007/978-3-030-58653-9_3           2           389  2020
# 2          10.1061/(ASCE)HY.1943-7900.0001822           3           216  2020
# 3                           10.1115/1.4047428           4            21  2018
# 4                  10.1016/j.tele.2020.101448           5           133  2018
# ..                                        ...         ...           ...   ...
# 872                       10.2514/6.2017-5341         873           311  2016
# 873                     10.1201/9781315369259         874           353  2015
# 874  10.1016/j.ijheatmasstransfer.2017.05.046         875            79  2016
# 875              10.1007/978-3-319-52392-7_91         876           360  2017
# 876                                       NaN         877           229  2015
#
#      ID_y                                               name              Type
# 0     198  International Conference on Transportation and...  Conference Paper
# 1     389                   AAAI Workshop - Technical Report  Conference Paper
# 2     216                          Advances in Heat Transfer  Conference Paper
# 3      21  Proceedings - 2020 IEEE 21st International Con...  Conference Paper
# 4     133               IEEE Radiation Effects Data Workshop  Conference Paper
# ..    ...                                                ...               ...
# 872   311  Proceedings of the 20th International Conferen...  Conference Paper
# 873   353    International Journal of Human Computer Studies           Journal
# 874    79  Proceedings - Annual Reliability and Maintaina...  Conference Paper
# 875   360  Proceedings - 2017 IEEE 17th International Con...  Conference Paper
# 876   229                                   Science Robotics  Conference Paper
#
# [877 rows x 10 columns]

# %%
total = len(articles_publishedin)
nb_joun = int(total * 0.2)
nb_workshop = int(total * 0.3)
nb_symposium = int(total * 0.5)

# %%
journals = articles_publishedin.loc[:nb_joun]
workshops = articles_publishedin.loc[nb_joun : nb_joun + nb_workshop]
symposium = articles_publishedin.loc[nb_joun + nb_workshop : ]

# %%
journals
# Out:
#      ID_x                                              title     volume  \
# 0       1  Self-assessment of Proficiency of Intelligent ...  1210 AISC
# 1       2  Bridging theory to practice: Feedforward and c...   695 LNEE
# 2       3  Development of sediment management guidelines ...        146
# 3       4  Structural design space exploration using prin...         20
# 4       5  Religion-focused dating apps: A Q methodology ...         55
# ..    ...                                                ...        ...
# 171   172  Free Space Excitation in Optofluidic Devices f...        NaN
# 172   173  Multiplexed Detection of Single Antibiotic Dru...        NaN
# 173   174  Three-Dimensional Hydrodynamic Focusing Design...        NaN
# 174   175  Transparency: Transitioning From Human–Machine...         13
# 175   176  An 8-bit 10-GHz 21-mW Time-Interleaved SAR ADC...          2
#
#                                     DOI  article_ID  publisher_ID  year  ID_y  \
# 0          10.1007/978-3-030-51758-8_15           1           198  2020   198
# 1           10.1007/978-3-030-58653-9_3           2           389  2020   389
# 2    10.1061/(ASCE)HY.1943-7900.0001822           3           216  2020   216
# 3                     10.1115/1.4047428           4            21  2018    21
# 4            10.1016/j.tele.2020.101448           5           133  2018   133
# ..                                  ...         ...           ...   ...   ...
# 171          10.1109/IPCon.2019.8908404         172           326  2019   326
# 172          10.1109/IPCon.2019.8908388         173            97  2017    97
# 173          10.1109/IPCon.2019.8908414         174           311  2018   311
# 174            10.1177/1555343419842776         175           295  2017   295
# 175           10.1109/LSSC.2019.2931440         176            62  2019    62
#
#                                                   name              Type
# 0    International Conference on Transportation and...  Conference Paper
# 1                     AAAI Workshop - Technical Report  Conference Paper
# 2                            Advances in Heat Transfer  Conference Paper
# 3    Proceedings - 2020 IEEE 21st International Con...  Conference Paper
# 4                 IEEE Radiation Effects Data Workshop  Conference Paper
# ..                                                 ...               ...
# 171  Proceedings of the International Conference on...  Conference Paper
# 172     IEEE Aerospace and Electronic Systems Magazine  Conference Paper
# 173  Proceedings of the 20th International Conferen...  Conference Paper
# 174                                Fire Safety Journal           Journal
# 175  Journal of Manufacturing and Materials Processing           Journal
#
# [176 rows x 10 columns]

# %%
venue_type_list = [journals,workshops,symposium]
venue_sub_type_ls = ["Journal","Workshop","Symposium"]

# %%
for i,venue_tp in enumerate(venue_type_list):

    venue_type = venue_sub_type_ls[i]
    venue_sub_type = URIRef(f"http://kg_sdm.org/{venue_type}")

    for index,row in venue_tp.iterrows():
        year = row['year']
        year_literal = Literal(int(year))
        submissiontitle = row['title']
        confname = row['name']
        
        # parsing conference
        conf_title = URLparse(confname)
        conf_node = URIRef(f"http://kg_sdm.org/venue/{conf_title}")
        venue_lit = Literal(str(conf_title))

        # parsing submission
        sub_title = URLparse(submissiontitle)
        sub_node = URIRef(f"http://kg_sdm.org/Submission/{sub_title}")

        
        # parsing for publication
        # assuming only half of the articles got accepted
        if index%2 == 0:
            if venue_type=='Journal':
                Pub_title = conf_title+'_volume_'+str(random.randint(1, 5))
                Pub_title_lit = Literal(str(Pub_title))
                
                pub_node = URIRef(f"http://kg_sdm.org/Publication/{Publication_title}")
                g.add(pub_node, RDF.type, KG_SDM.Volume)
                g.add(sub_node,KG_SDM.published_in,pub_node)
                g.add(pub_node, KG_SDM.publication_title,Pub_title_lit)
                g.add(pub_node, KG_SDM.publication_year,year_literal)

            # if (venue_type=='Workshop' or venue_type=='Symposium')
            else:
                Pub_title = conf_title+'_proceddings_'
                Pub_title_lit = Literal(str(Pub_title))
                
                pub_node = URIRef(f"http://kg_sdm.org/Publication/{Publication_title}")
                g.add(pub_node, RDF.type, KG_SDM.Proceddings)
                g.add(sub_node,KG_SDM.published_in,pub_node)
                g.add(pub_node, KG_SDM.publication_title,Pub_title_lit)
                g.add(pub_node, KG_SDM.publication_year,year_literal)



        # add subclass type
        g.add((conf_node, RDF.type, venue_sub_type))
        # add name of venue
        g.add((conf_node, KG_SDM.venue_title, venue_lit))

        # connect conference and submission
        g.add((sub_node,KG_SDM.submitted_to,conf_node))

# %%
print(g.serialize('abox.ttl', format="ttl"))
# Out:
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'Memory']].

# %%
print(g.serialize())
# Out:
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix kg_sdm: <http://kg_sdm.org/> .
#
# kg_sdm:Aarsnes_U_J_ a kg_sdm:Chair,
#         kg_sdm:Reviewers ;
#     kg_sdm:school " Cardiff University Brain Research Imaging Centre (CUBRIC), Cardiff University, Cardiff, United Kingdom" ;
#     foaf:name "Aarsnes U.J." .
#
# kg_sdm:Abaimov_S_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Biology, Utah Valley University, SB 242M, Orem, UT  84058, United States" ;
#     foaf:name "Abaimov S." .
#
# kg_sdm:Abildskov_T_J_ a kg_sdm:Editor ;
#     kg_sdm:school " Department of Physics and Astronomy, KU Leuven, Celestijnenlaan 200D, Heverlee, B-3001, Belgium" ;
#     foaf:name "Abildskov T.J." .
#
# kg_sdm:Abliz_D_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Instructional Psychology and Technology, Brigham Young University, 150-H MCKB, Provo, UT  84602, United States" ;
#     foaf:name "Abliz D." .
#
# kg_sdm:Abut_F_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Marriott School of Management, Brigham Young Univ., 730 TNRB, Provo, UT  84602-3113, United States" ;
#     foaf:name "Abut F." .
#
# kg_sdm:Ackerman_W_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Department of Chemical Engineering, Brigham Young University, 350 Clyde Building, Provo, UT  84604, United States" ;
#     foaf:name "Ackerman W." .
#
# kg_sdm:Adams_B_R_ a kg_sdm:Author ;
#     kg_sdm:school " National Science Foundation, Center for Space, High-performance, Resilient Computing" ;
#     foaf:name "Adams B.R." .
#
# kg_sdm:Adams_D_ a kg_sdm:Chair ;
#     kg_sdm:school " Dept. of Agricultural and Biochemical Engineering, Univ. of Florida, 281 Frazier Rogers Hall, Gainesville, FL  32611, United States" ;
#     foaf:name "Adams D." .
#
# kg_sdm:Adams_D_W_ a kg_sdm:Author ;
#     kg_sdm:school "Univ Lyon, CNRS, INSA-Lyon, Université Claude Bernard Lyon 1, CETHIL UMR5008, Villeurbanne, F-69621, France" ;
#     foaf:name "Adams D.W." .
#
# kg_sdm:Adams_J_A_ a kg_sdm:Author ;
#     kg_sdm:school " University of Colorado, Boulder, United States" ;
#     foaf:name "Adams J.A." .
#
# kg_sdm:Adams_M_R_ a kg_sdm:Reviewers ;
#     kg_sdm:school " IP and Optical Dept, Nokia Networks, Ankara, Turkey" ;
#     foaf:name "Adams M.R." .
#
# kg_sdm:Adamson_M_ a kg_sdm:Author ;
#     kg_sdm:school "University of Minnesota Duluth, United States" ;
#     foaf:name "Adamson M." .
#
# kg_sdm:Adidharma_H_ a kg_sdm:Author ;
#     kg_sdm:school " Instructional Psychology & Technology, McKay School of Education, Brigham Young University, Provo, UT, United States" ;
#     foaf:name "Adidharma H." .
#
# kg_sdm:Advani_S_G_ a kg_sdm:Author ;
#     kg_sdm:school " 2420 Briarwood Lane, Eustis, FL  32726, United States" ;
#     foaf:name "Advani S.G." .
#
# kg_sdm:Afran_M_S_ a kg_sdm:Author ;
#     kg_sdm:school "Department of Chemical Engineering, Brigham Young University, Provo, UT  84604, United States" ;
#     foaf:name "Afran M.S." .
#
# kg_sdm:Aghito_M_ a kg_sdm:Author ;
#     kg_sdm:school " National Research Council, Air Force Research Laboratory, Eglin Air Force Base, Valparaiso, FL  32542, United States" ;
#     foaf:name "Aghito M." .
#
# kg_sdm:Ahrens_J_ a kg_sdm:Author ;
#     kg_sdm:school "Department of Chemical Engineering, University of Utah, Salt Lake City, UT, United States" ;
#     foaf:name "Ahrens J." .
#
# kg_sdm:Akagi_J_ a kg_sdm:Author ;
#     kg_sdm:school " Shell Development Co, United States" ;
#     foaf:name "Akagi J." .
#
# kg_sdm:Akay_M_F_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Buried Asset Management Infrastructure-International, Louisiana Tech Univ., 1207 Agriculture Dr., Ruston, LA  71270, United States" ;
#     foaf:name "Akay M.F." .
#
# kg_sdm:Akhatov_I_ a kg_sdm:Author ;
#     kg_sdm:school " Center for Computing Research, Sandia National Laboratories, Albuquerque, NM  87185, United States" ;
#     foaf:name "Akhatov I." .
#
# kg_sdm:Aktas_A_ a kg_sdm:Author ;
#     kg_sdm:school " 41240 12th St. West, Palmdale, CA  93551, United States" ;
#     foaf:name "Aktas A." .
#
# kg_sdm:Alcock_C_ a kg_sdm:Editor ;
#     kg_sdm:school " Department of Mechanical Engineering, United States" ;
#     foaf:name "Alcock C." .
#
# kg_sdm:Aldous_P_ a kg_sdm:Author ;
#     kg_sdm:school "University of Tennessee, United States" ;
#     foaf:name "Aldous P." .
#
# kg_sdm:Alejandro_A_ a kg_sdm:Author ;
#     kg_sdm:school " Electrical and Computer Engineering, Brigham Young University, 6756 Provo, Utah United States (e-mail: hygunth@gmail.com)" ;
#     foaf:name "Alejandro A." .
#
# kg_sdm:Ali_M_A_ a kg_sdm:Author ;
#     kg_sdm:school " Nuclear Science and Engineering Directorate, Japan Atomic Energy Agency (JAEA), 2-4 Shirane, Shirakata, Tokai-mura, Naka-gun, Ibaraki  319-1195, Japan" ;
#     foaf:name "Ali M.A." .
#
# kg_sdm:Alin_F_ a kg_sdm:Chair ;
#     kg_sdm:school "Swift Engineering and Radiation Services, San José, CA, United States" ;
#     foaf:name "Alin F." .
#
# kg_sdm:Allen_B_C_ a kg_sdm:Author ;
#     kg_sdm:school " University of Calgary, Canada" ;
#     foaf:name "Allen B.C." .
#
# kg_sdm:Allen_D_ a kg_sdm:Author ;
#     kg_sdm:school " University of Minnesota, United States" ;
#     foaf:name "Allen D." .
#
# kg_sdm:Allen_G_N_ a kg_sdm:Author ;
#     kg_sdm:school " Computer Science Department, Brigham Young University, Provo, UT, United States" ;
#     foaf:name "Allen G.N." .
#
# kg_sdm:Allen_J_D_ a kg_sdm:Author ;
#     kg_sdm:school " Purdue University, West Lafayette, United States" ;
#     foaf:name "Allen J.D." .
#
# kg_sdm:Allen_M_ a kg_sdm:Author ;
#     kg_sdm:school " Semiconductor Research Corp, 4819 Emperor Blvd., Durham, NC  27703, United States" ;
#     foaf:name "Allen M." .
#
# kg_sdm:Allen_Q_S_ a kg_sdm:Author ;
#     kg_sdm:school "Purdue University, School of Engineering Education at Purdue, West Lafayette, United States" ;
#     foaf:name "Allen Q.S." .
#
# kg_sdm:Allen_T_D_ a kg_sdm:Author ;
#     kg_sdm:school " Center for Applied Scientific Computing, Lawrence Livermore National Laboratory, P. O. Box 8080, L-561, Livermore, CA  94551, United States" ;
#     foaf:name "Allen T.D." .
#
# kg_sdm:Allender_E_J_ a kg_sdm:Chair ;
#     kg_sdm:school " Department of Mathematics, University of Wyoming, Laramie, WY  82071, United States" ;
#     foaf:name "Allender E.J." .
#
# kg_sdm:Allred_D_D_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Department of Engineering Education, Utah State University, Logan, UT, United States" ;
#     foaf:name "Allred D.D." .
#
# kg_sdm:Almeida_N_V_ a kg_sdm:Chair ;
#     kg_sdm:school "Center for Infrastructure, Energy, and Space Testing, University of Colorado Boulder, Boulder, CO, United States" ;
#     foaf:name "Almeida N.V." .
#
# kg_sdm:Ames_D_C_ a kg_sdm:Author ;
#     kg_sdm:school "Department of Exercise Sciences, Brigham Young University, Provo, UT, United States" ;
#     foaf:name "Ames D.C." .
#
# kg_sdm:Amin_M_N_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Architecture and Urbanism, University Presbiteriana Mackenzie - UPM, São Paulo, Brazil" ;
#     foaf:name "Amin M.N." .
#
# kg_sdm:Amini_E_ a kg_sdm:Author ;
#     kg_sdm:school "Mechanical Engineering Department, Brigham Young University, Provo, UT, United States" ;
#     foaf:name "Amini E." .
#
# kg_sdm:Andersen_J_ a kg_sdm:Author ;
#     kg_sdm:school " Education and Technology, Royal Roads University, Victoria, Canada" ;
#     foaf:name "Andersen J." .
#
# kg_sdm:Anderson_B_B_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Aerodyne Industries, LLC, Houston, TX, United States" ;
#     foaf:name "Anderson B.B." .
#
# kg_sdm:Anderson_B_E_ a kg_sdm:Author ;
#     kg_sdm:school " University of New Hampshire, Department of Mechanical Engineering, Durham, NH  03824, United States" ;
#     foaf:name "Anderson B.E." .
#
# kg_sdm:Anderson_C_M_ a kg_sdm:Chair ;
#     kg_sdm:school " Department of Civil and Environmental Engineering, University of Connecticut, Storrs, CT, United States" ;
#     foaf:name "Anderson C.M." .
#
# kg_sdm:Anderson_C_R_ a kg_sdm:Author ;
#     kg_sdm:school " Sensors, Air Force Research Laboratory, 1864 4th St, Wright-Patterson AFB, OH  45433, United States" ;
#     foaf:name "Anderson C.R." .
#
# kg_sdm:Anderson_J_ a kg_sdm:Author,
#         kg_sdm:Reviewers ;
#     kg_sdm:school " Detonation Science and Technology (Q-6), Los Alamos National Laboratory, Los Alamos, NM, United States",
#         " Utah State Univ. (USU), Buried Structures Laboratory, 3000 Old Main Hill, Logan, UT  84322, United States" ;
#     foaf:name "Anderson J." .
#
# kg_sdm:Anderson_M_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Dept. of Physics and AstronomyN283 ESC, Canada" ;
#     foaf:name "Anderson M." .
#
# kg_sdm:Anderson_R_ a kg_sdm:Author ;
#     kg_sdm:school "School of Physical Science and Technology, Southwest Jiaotong University, Chengdu, Sichuan, China" ;
#     foaf:name "Anderson R." .
#
# kg_sdm:Anderson_S_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Kansas State University, Manhattan, KS, United States" ;
#     foaf:name "Anderson S." .
#
# kg_sdm:Andersson_K_ a kg_sdm:Author ;
#     kg_sdm:school " School of Information Science and Engineering, Lanzhou University, Lanzhou, China" ;
#     foaf:name "Andersson K." .
#
# kg_sdm:Andrews_D_W_ a kg_sdm:Reviewers ;
#     kg_sdm:school "Manufacturing Engineering Technology, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Andrews D.W." .
#
# kg_sdm:André_F_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Peerless Technologies Corporation, 2300 National Rd, Beavercreek, OH  45324, United States" ;
#     foaf:name "André F." .
#
# kg_sdm:Annoni_J_ a kg_sdm:Reviewers ;
#     kg_sdm:school "Department of Electrical and Computer Engineering, Brigham Young University, 459 Clyde Building, Provo, UT  84602, United States" ;
#     foaf:name "Annoni J." .
#
# kg_sdm:Arabian_F_ a kg_sdm:Reviewers ;
#     kg_sdm:school "Department of Mechanical Engineering, Brigham Young University, Provo, Utah, 84602, United States" ;
#     foaf:name "Arabian F." .
#
# kg_sdm:Arango_A_ a kg_sdm:Author ;
#     kg_sdm:school " Harvard-Smithsonian Center for Astrophysics, Cambridge, MA, United States" ;
#     foaf:name "Arango A." .
#
# kg_sdm:Arashida_Y_ a kg_sdm:Reviewers ;
#     kg_sdm:school " College of Medicine, School of Health and Rehabilitation Sciences, Division of Health Information Management and Systems, United States" ;
#     foaf:name "Arashida Y." .
#
# kg_sdm:Arce_S_ a kg_sdm:Author ;
#     kg_sdm:school " Univ Lyon, CNRS, INSA-Lyon, Université Claude Bernard Lyon 1, CETHIL UMR5008, Villeurbanne, F-69621, France" ;
#     foaf:name "Arce S." .
#
# kg_sdm:Argyle_M_ a kg_sdm:Author ;
#     kg_sdm:school " Mechanical Engineering Department, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Argyle M." .
#
# kg_sdm:Armknecht_J_ a kg_sdm:Reviewers ;
#     kg_sdm:school " RMRS Missoula Fire Sciences Laboratory, USDA Forest Service, Missoula, MT  59808, United States" ;
#     foaf:name "Armknecht J." .
#
# kg_sdm:Armstrong_A_G_ a kg_sdm:Reviewers ;
#     kg_sdm:school "Dept. of Civil and Environmental Engineering, Brigham Young Univ., 376 Clyde Building, Provo, UT  84602, United States" ;
#     foaf:name "Armstrong A.G." .
#
# kg_sdm:Arnold_B_T_ a kg_sdm:Author ;
#     kg_sdm:school "Department of Engineering Leadership, Ira A. Fulton College of Engineering and Technology, Brigham Young University (BYU), United States" ;
#     foaf:name "Arnold B.T." .
#
# kg_sdm:Arya_M_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Materials Science and Engineering, The Ohio State University, Columbus, OH, United States" ;
#     foaf:name "Arya M." .
#
# kg_sdm:Aryal_B_R_ a kg_sdm:Author ;
#     kg_sdm:school " Air Force Research Laboratory, Department of Mechanical Engineering, Wright–Patterson Air Force BaseOH  45433, United States" ;
#     foaf:name "Aryal B.R." .
#
# kg_sdm:Ashcraft_C_C_ a kg_sdm:Author ;
#     kg_sdm:school " NASA Langley Research Center, Hampton, VA  23681, United States" ;
#     foaf:name "Ashcraft C.C." .
#
# kg_sdm:Ashe_J_ a kg_sdm:Editor ;
#     kg_sdm:school " Columbia Basin Agricultural Research Center, Oregon State University, Pendleton, OR, United States" ;
#     foaf:name "Ashe J." .
#
# kg_sdm:Ashida_M_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Guiana Space Center, Flight Safety Department of CNES/CSG, French Guiana" ;
#     foaf:name "Ashida M." .
#
# kg_sdm:Asimaki_D_ a kg_sdm:Author ;
#     kg_sdm:school "Dept. of Electrical and Computer Eng, Tufts University, Medford, MA, United States" ;
#     foaf:name "Asimaki D." .
#
# kg_sdm:Atkinson_N_ a kg_sdm:Author ;
#     kg_sdm:school "Mechanical Engineering Department, Brigham Young University, Provo, United States" ;
#     foaf:name "Atkinson N." .
#
# kg_sdm:Austin_D_E_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Chemical Engineering, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Austin D.E." .
#
# kg_sdm:Avila_A_ a kg_sdm:Author ;
#     kg_sdm:school "Institute of Thermal Science and Technology, Shandong University, Jinan, Shandong  250061, China" ;
#     foaf:name "Avila A." .
#
# kg_sdm:Avval_T_G_ a kg_sdm:Reviewers ;
#     kg_sdm:school "WDP and Associates, 10621 Gateway Blvd., Suite 200, Manassas, VA  20110, United States" ;
#     foaf:name "Avval T.G." .
#
# kg_sdm:Awerkamp_P_ a kg_sdm:Author ;
#     kg_sdm:school " University of Turku, Turun yliopistoFI-20014, Finland" ;
#     foaf:name "Awerkamp P." .
#
# kg_sdm:Ayoubi_P_ a kg_sdm:Reviewers ;
#     kg_sdm:school " School of Earth and Space Exploration, Arizona State University, Tempe, AZ  85287, United States" ;
#     foaf:name "Ayoubi P." .
#
# kg_sdm:Ba_Q_ a kg_sdm:Reviewers ;
#     kg_sdm:school "Department of Chemical Engineering, 350 Clyde Building, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Ba Q." .
#
# kg_sdm:Babaei_A_ a kg_sdm:Author ;
#     kg_sdm:school "Brigham Young University, Department Electrical and Computer Engineering, Provo, United States" ;
#     foaf:name "Babaei A." .
#
# kg_sdm:Badger_J_C_ a kg_sdm:Author ;
#     kg_sdm:school " Qatar Computing Research Institute, Hamad bin Khalifa University, Qatar" ;
#     foaf:name "Badger J.C." .
#
# kg_sdm:Baer_D_R_ a kg_sdm:Chair ;
#     kg_sdm:school " Department of Chemistry, St. Olaf College, Northfield, Minnesota  55057, United States" ;
#     foaf:name "Baer D.R." .
#
# kg_sdm:Bahari_M_ a kg_sdm:Author ;
#     kg_sdm:school " Institute for Analysis and Scientific Computing, TU Wien, Vienna, 1040, Austria" ;
#     foaf:name "Bahari M." .
#
# kg_sdm:Bai_H_ a kg_sdm:Reviewers ;
#     kg_sdm:school " National Wind Technology Center, 18200 CO-128, Boulder, CO  80303, United States" ;
#     foaf:name "Bai H." .
#
# kg_sdm:Bair_J_ a kg_sdm:Author ;
#     kg_sdm:school "Mechanical Engineering, Brigham Young University, Provo, UT, United States" ;
#     foaf:name "Bair J." .
#
# kg_sdm:Baird_S_ a kg_sdm:Author ;
#     kg_sdm:school " University of Arkansas, Fayetteville, AR, United States" ;
#     foaf:name "Baird S." .
#
# kg_sdm:Baker_M_J_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Power Engineering, Jadavpur University, Kolkata, 700098, India" ;
#     foaf:name "Baker M.J." .
#
# kg_sdm:Baker_N_F_ a kg_sdm:Reviewers ;
#     kg_sdm:school " TRC, Taylorsville, UT  84321, United States" ;
#     foaf:name "Baker N.F." .
#
# kg_sdm:Baker_W_H_ a kg_sdm:Author ;
#     kg_sdm:school " Corporate Research and Engineering, Kimberly-Clark Corporation, Neenah, WI  54956, United States" ;
#     foaf:name "Baker W.H." .
#
# kg_sdm:Banesh_D_ a kg_sdm:Author ;
#     kg_sdm:school " School of Electronics and Information Technology, Sun Yat-sen University, China" ;
#     foaf:name "Banesh D." .
#
# kg_sdm:Bangerter_N_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Sustainable Solutions Corporation, 155 Railroad Plaza, Royersford, PA  19468, United States" ;
#     foaf:name "Bangerter N." .
#
# kg_sdm:Banik_J_A_ a kg_sdm:Reviewers ;
#     kg_sdm:school " US Geological Survey, Astrogeology Division, Flagstaff, AZ  86001, United States" ;
#     foaf:name "Banik J.A." .
#
# kg_sdm:Bannister_M_T_ a kg_sdm:Editor ;
#     kg_sdm:school " Department of Electrical and Computer Engineering, United States" ;
#     foaf:name "Bannister M.T." .
#
# kg_sdm:Baptista_A_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Department of Health Science, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Baptista A." .
#
# kg_sdm:Baradoy_D_ a kg_sdm:Editor ;
#     kg_sdm:school " Centre de Thermique et d’Energétique de Lyon, INSA de Lyon, 9 rue de la Physique, Villeurbanne, 69621, France" ;
#     foaf:name "Baradoy D." .
#
# kg_sdm:Barber_J_L_ a kg_sdm:Author ;
#     kg_sdm:school "Mechanical Engineering, Brigham Young University, 350 EB, Provo, UT  84602, United States" ;
#     foaf:name "Barber J.L." .
#
# kg_sdm:Barnwell_N_V_ a kg_sdm:Chair ;
#     kg_sdm:school " Computational Biology Institute, George Washington University, Washington, DC  20052, United States" ;
#     foaf:name "Barnwell N.V." .
#
# kg_sdm:Barreto_D_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Univ. of Tennessee, United States" ;
#     foaf:name "Barreto D." .
#
# kg_sdm:Barrett_B_J_ a kg_sdm:Author ;
#     kg_sdm:school "Aix-Marseille Université, IUSTI/ UMR CNRS 7343, 5 rue E. Fermi, Marseille, 13453, France" ;
#     foaf:name "Barrett B.J." .
#
# kg_sdm:Barrios_J_A_ a kg_sdm:Editor ;
#     kg_sdm:school " Department of Control and Dynamical Systems, California Institute of Technology, Pasadena, CA  91125, United States" ;
#     foaf:name "Barrios J.A." .
#
# kg_sdm:Barter_M_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Physics and Astronomy, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Barter M." .
#
# kg_sdm:Barton_T_J_ a kg_sdm:Author ;
#     kg_sdm:school "Brigham Young University, Ira A. Fulton College of Engineering and Technology, United States" ;
#     foaf:name "Barton T.J." .
#
# kg_sdm:Bartschi_J_M_ a kg_sdm:Author ;
#     kg_sdm:school " Faculty of Technical Sciences, Dept. of Power Electronics and Com. Engineering, Novi Sad, Serbia" ;
#     foaf:name "Bartschi J.M." .
#
# kg_sdm:Baskota_A_ a kg_sdm:Editor ;
#     kg_sdm:school "Brigham Young University, Department of Chemical Engineering, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Baskota A." .
#
# kg_sdm:Bateman_T_C_ a kg_sdm:Editor ;
#     kg_sdm:school " Ford Motor Company, Dearborn, MI, United States" ;
#     foaf:name "Bateman T.C." .
#
# kg_sdm:Bates_C_O_ a kg_sdm:Author ;
#     kg_sdm:school "Department of Mechanical Engineering 350 EB, Brigham Young University, Provo UT 84602, United States" ;
#     foaf:name "Bates C.O." .
#
# kg_sdm:Bathe_M_ a kg_sdm:Reviewers ;
#     kg_sdm:school "Department of mechanical of mechanical engineering, Brigham Young University, 435 CTB, Provo, UT  84602, United States" ;
#     foaf:name "Bathe M." .
#
# kg_sdm:Bauer_J_M_ a kg_sdm:Editor ;
#     kg_sdm:school " University of Florida, Shalimar, FL  32579, United States" ;
#     foaf:name "Bauer J.M." .
#
# kg_sdm:Baumgarten_T_E_ a kg_sdm:Author ;
#     kg_sdm:school "Dept. of Mechanical Engineering, Brigham Young University, Provo, UT  84604, United States" ;
#     foaf:name "Baumgarten T.E." .
#
# kg_sdm:Baxter_J_S_ a kg_sdm:Author ;
#     kg_sdm:school " School of Chemical Engineering, College of Engineering, University of Tehran, Tehran, Iran" ;
#     foaf:name "Baxter J.S." .
#
# kg_sdm:Baxter_L_L_ a kg_sdm:Author ;
#     kg_sdm:school "Ira A Fulton College of Engineering and Technology, Brigham Young Univ., Provo, UT  84602, United States" ;
#     foaf:name "Baxter L.L." .
#
# kg_sdm:Bean_M_ a kg_sdm:Editor ;
#     kg_sdm:school " Fermi National Accelerator Laboratory, Batavia, IL  60510, United States" ;
#     foaf:name "Bean M." .
#
# kg_sdm:Beard_J_D_ a kg_sdm:Author ;
#     kg_sdm:school "Brigham Young University, Department of Mechanical Engineering, 360 EB, Provo, UT  84602, United States" ;
#     foaf:name "Beard J.D." .
#
# kg_sdm:Beard_R_W_ a kg_sdm:Author ;
#     kg_sdm:school " Chemistry and Biochemistry Department, Brigham Young University, Provo, Utah  84602, United States" ;
#     foaf:name "Beard R.W." .
#
# kg_sdm:Beauchamp_M_J_ a kg_sdm:Editor ;
#     kg_sdm:school "Combustion Science & Engineering, Inc., Columbia, MD, United States" ;
#     foaf:name "Beauchamp M.J." .
#
# kg_sdm:Behounek_M_ a kg_sdm:Chair ;
#     kg_sdm:school " Department of Statistics, Brigham Young University, Provo, United States" ;
#     foaf:name "Behounek M." .
#
# kg_sdm:Bekker_B_ a kg_sdm:Author ;
#     kg_sdm:school "Mechanical Engineering, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Bekker B." .
#
# kg_sdm:Belanger_H_ a kg_sdm:Editor ;
#     kg_sdm:school " University of Texas at Dallas, Richardson, TX, United States" ;
#     foaf:name "Belanger H." .
#
# kg_sdm:Bencivenga_F_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Mechanical Engineering, The University of Texas at Dallas, Richardson, TX, United States" ;
#     foaf:name "Bencivenga F." .
#
# kg_sdm:Benson_D_ a kg_sdm:Author ;
#     kg_sdm:school " Dept. of Psychology and Neuroscience, Computer Science, and Clinical Immunology Clinical Systems Biology Group, Inst. for Neuroimmune Medicine Nova Southeastern University, Fort Lauderdale, FL, United States" ;
#     foaf:name "Benson D." .
#
# kg_sdm:Berg_D_C_ a kg_sdm:Author ;
#     kg_sdm:school " MITRE Corporation, 7596 Colshire Drive, McLean, VA  22102-7539, United States" ;
#     foaf:name "Berg D.C." .
#
# kg_sdm:Bergen_B_K_ a kg_sdm:Chair ;
#     kg_sdm:school " LLC, San Jose, CA  95124, United States" ;
#     foaf:name "Bergen B.K." .
#
# kg_sdm:Berselli_G_ a kg_sdm:Author ;
#     kg_sdm:school " University of Arkansas, United States" ;
#     foaf:name "Berselli G." .
#
# kg_sdm:Best_C_M_ a kg_sdm:Author ;
#     kg_sdm:school "Frontier-Kemper Constructors, Inc., 1695 Allen Rd., Evansville, IN  47710, United States" ;
#     foaf:name "Best C.M." .
#
# kg_sdm:Beutler_J_ a kg_sdm:Author ;
#     kg_sdm:school "Brigham Young University, Provo, UT  84601, United States" ;
#     foaf:name "Beutler J." .
#
# kg_sdm:Beyerlein_I_J_ a kg_sdm:Author ;
#     kg_sdm:school "Sandia National Laboratories, Albuquerque, NM  87123, United States" ;
#     foaf:name "Beyerlein I.J." .
#
# kg_sdm:Beyzaei_C_ a kg_sdm:Author ;
#     kg_sdm:school "Department of Electrical and Computer Engineering, University of Coimbra, Portugal" ;
#     foaf:name "Beyzaei C." .
#
# kg_sdm:Bhamra_T_ a kg_sdm:Reviewers ;
#     kg_sdm:school " College of Information Engineering, China Jiliang University, Hangzhou, 310018, China" ;
#     foaf:name "Bhamra T." .
#
# kg_sdm:Bickerton_S_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Mathematics, University of Exeter, Exeter, EX4 4QF, United Kingdom" ;
#     foaf:name "Bickerton S." .
#
# kg_sdm:Bickham_B_P_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Electrical and Computer Engineering, Brigham Young University, Provo, UT 84602 USA." ;
#     foaf:name "Bickham B.P." .
#
# kg_sdm:Bidstrup_C_C_ a kg_sdm:Author ;
#     kg_sdm:school " State Key Laboratory for Manufacturing Systems Engineering and Shaanxi Key Lab of Intelligent Robots, Xi’an Jiaotong University, Xi’an, China" ;
#     foaf:name "Bidstrup C.C." .
#
# kg_sdm:Bigler_E_D_ a kg_sdm:Editor ;
#     kg_sdm:school " Department of Mechanical and Aerospace Engineering, Utah State University, 4130 Old Main Hill, Logan, UT  84322, United States" ;
#     foaf:name "Bigler E.D." .
#
# kg_sdm:Bilancia_P_ a kg_sdm:Author ;
#     kg_sdm:school " California Institute of Technology, United States" ;
#     foaf:name "Bilancia P." .
#
# kg_sdm:Bilodeau_R_A_ a kg_sdm:Author ;
#     kg_sdm:school "Division of Decision and Control Systems, KTH Royal Institute of Technology, Stockholm, 11428, Sweden" ;
#     foaf:name "Bilodeau R.A." .
#
# kg_sdm:Bingham_E_ a kg_sdm:Author ;
#     kg_sdm:school " Wagstaff Crane Service, 4315 S. Commerce Dr., Murray, UT  84107, United States" ;
#     foaf:name "Bingham E." .
#
# kg_sdm:Bischoff_M_ a kg_sdm:Author ;
#     kg_sdm:school "Brigham Young University Provo, Computer Science Department Computer Science Department, Utah, 84602, United States" ;
#     foaf:name "Bischoff M." .
#
# kg_sdm:Biswas_A_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Statistics, Brigham Young University, United States" ;
#     foaf:name "Biswas A." .
#
# kg_sdm:Biwer_C_M_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Electrical and Computer Engineering, Brigham Young University, United States" ;
#     foaf:name "Biwer C.M." .
#
# kg_sdm:Bjoraker_G_L_ a kg_sdm:Editor ;
#     kg_sdm:school " AFRL, University of Florida Research and Engineering Education Facility, United States" ;
#     foaf:name "Bjoraker G.L." .
#
# kg_sdm:Bjørkevoll_K_ a kg_sdm:Author ;
#     kg_sdm:school " Oak Ridge National Laboratory, Oak Ridge, TN  37830, United States" ;
#     foaf:name "Bjørkevoll K." .
#
# kg_sdm:Black_J_A_ a kg_sdm:Reviewers ;
#     kg_sdm:school "Brigham Young University, Dept. of Physics and Astronomy, N283 ESC, Provo, UT  84602, United States" ;
#     foaf:name "Black J.A." .
#
# kg_sdm:Black_R_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Blue Ridge Research and Consulting, 29 N Market St, Suite 700, Asheville, NC  28801, United States" ;
#     foaf:name "Black R." .
#
# kg_sdm:Blackburn_L_ a kg_sdm:Author ;
#     kg_sdm:school " ITC, Faculty of Geo-Information Science and Earth Observation, University of Twente, Enschede, Netherlands" ;
#     foaf:name "Blackburn L." .
#
# kg_sdm:Blonquist_J_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Dept. of Geotechnical and Structural Engineering, Pontificia Univ. Católica de Chile, Vicuña Mackenna 4860, Macul, Santiago, 7820436, Chile" ;
#     foaf:name "Blonquist J." .
#
# kg_sdm:Boardman_B_ a kg_sdm:Author ;
#     kg_sdm:school "School of Electronics and Information Technology, Sun Yat-sen University, Guangzhou, China" ;
#     foaf:name "Boardman B." .
#
# kg_sdm:Boaventura-Cunha_J_ a kg_sdm:Author ;
#     kg_sdm:school " Dept. of Civil and Environmental Engineering, Brigham Young Univ., 430 Engineering Bldg., Provo, UT  84602, United States" ;
#     foaf:name "Boaventura-Cunha J." .
#
# kg_sdm:Bodaghi_M_ a kg_sdm:Author ;
#     kg_sdm:school "National Institute of Clean-and-Low-Carbon Energy, Beijing, 102211, China" ;
#     foaf:name "Bodaghi M." .
#
# kg_sdm:Bodewits_D_ a kg_sdm:Editor ;
#     kg_sdm:school "Dept. of Civil and Environmental Engineering, Brigham Young Univ., 368 Clyde Bldg., Provo, UT  84602, United States" ;
#     foaf:name "Bodewits D." .
#
# kg_sdm:Bodily_R_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Chemical Engineering, Brigham Young University, 330 Engineering Building, Provo, UT  84602, United States" ;
#     foaf:name "Bodily R." .
#
# kg_sdm:Boekweg_E_ a kg_sdm:Author ;
#     kg_sdm:school "Department of Mechanical Engineering, Brigham Young University, Provo, UT  84604, United States" ;
#     foaf:name "Boekweg E." .
#
# kg_sdm:Bohman_M_ a kg_sdm:Reviewers ;
#     kg_sdm:school "Infrastructure Financial Consulting, 3507 North University Ave., Provo, UT  84604, United States" ;
#     foaf:name "Bohman M." .
#
# kg_sdm:Bohn_R_E_ a kg_sdm:Author ;
#     kg_sdm:school "Department of Civil and Environmental Engineering, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Bohn R.E." .
#
# kg_sdm:Bolme_C_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Mathematics, Brigham Young University, Provo, UT, United States" ;
#     foaf:name "Bolme C." .
#
# kg_sdm:Bong_H_J_ a kg_sdm:Author ;
#     kg_sdm:school "Henan University of Science and Technology, School of Information Engineering, Luoyang, China" ;
#     foaf:name "Bong H.J." .
#
# kg_sdm:Bonner_N_ a kg_sdm:Reviewers ;
#     kg_sdm:school "University of British Columbia, Canada" ;
#     foaf:name "Bonner N." .
#
# kg_sdm:Bopp_D_G_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Mechanical Engineering and Materials Science, Duke University, Durham, NC  27708, United States" ;
#     foaf:name "Bopp D.G." .
#
# kg_sdm:Borden_M_J_ a kg_sdm:Author ;
#     kg_sdm:school " Resource Systems Group, Inc., Salt Lake City, UT, United States" ;
#     foaf:name "Borden M.J." .
#
# kg_sdm:Bosh_A_S_ a kg_sdm:Editor ;
#     kg_sdm:school " SandME Inc., 620 Wando Park Blvd, Mt. Pleasant, SC  29464, United States" ;
#     foaf:name "Bosh A.S." .
#
# kg_sdm:Boster_K_ a kg_sdm:Author ;
#     kg_sdm:school " Cubiscan, Inc, Farmington, UT  84025, United States" ;
#     foaf:name "Boster K." .
#
# kg_sdm:Bourassa_M_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Department of Psychiatry, University of Pittsburgh, Pittsburgh, PA, United States" ;
#     foaf:name "Bourassa M." .
#
# kg_sdm:Bowden_A_E_ a kg_sdm:Author ;
#     kg_sdm:school " University of California at Santa Barbara, Santa Barbara, CA  93106, United States" ;
#     foaf:name "Bowden A.E." .
#
# kg_sdm:Bowen_L_ a kg_sdm:Chair ;
#     kg_sdm:school "Instructional Psychology and Technology Department, Brigham Young University, 150 MCKB, Provo, UT  84604, United States" ;
#     foaf:name "Bowen L." .
#
# kg_sdm:Bowlan_P_ a kg_sdm:Author ;
#     kg_sdm:school " Los Alamos National Laboratory, Los Alamos, NM, United States" ;
#     foaf:name "Bowlan P." .
#
# kg_sdm:Bowman_E_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Dept. Civil, Arch. Env. Engineering, Univ. of l'Aquila, L'Aquila, 67100, Italy" ;
#     foaf:name "Bowman E." .
#
# kg_sdm:Boyce_P_ a kg_sdm:Chair ;
#     kg_sdm:school " WHOlives.org, South Jordan, UT  84095, United States" ;
#     foaf:name "Boyce P." .
#
# kg_sdm:Bradley_M_W_ a kg_sdm:Author ;
#     kg_sdm:school " International College of Semiconductor Technology, National Chiao Tung University, Hsinchu, 30010, Taiwan" ;
#     foaf:name "Bradley M.W." .
#
# kg_sdm:Bresciano_K_A_ a kg_sdm:Editor ;
#     kg_sdm:school " Raytheon Missile Systems, Tucson, AZ  85756, United States" ;
#     foaf:name "Bresciano K.A." .
#
# kg_sdm:Brewer_E_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Mathematics, Brigham Young University, TMCB 274, Provo, UT  84602, United States" ;
#     foaf:name "Brewer E." .
#
# kg_sdm:Briceño_X_ a kg_sdm:Reviewers ;
#     kg_sdm:school "Lucid Software Inc, United States" ;
#     foaf:name "Briceño X." .
#
# kg_sdm:Brink_K_M_ a kg_sdm:Author ;
#     kg_sdm:school "Brigham Young University, United States" ;
#     foaf:name "Brink K.M." .
#
# kg_sdm:Brock_Kirwan_C_ a kg_sdm:Reviewers ;
#     kg_sdm:school "Astro Technology, Inc., Houston, TX, United States" ;
#     foaf:name "Brock Kirwan C." .
#
# kg_sdm:Broderick_G_ a kg_sdm:Author ;
#     kg_sdm:school " U.S. Air Force Research Laboratory, Battlespace Acoustics Branch, Building 441, 2610 Seventh Street, Wright–Patterson Air Force Base, OH  45433, United States" ;
#     foaf:name "Broderick G." .
#
# kg_sdm:Brodie_M_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Brigham Young University, Department of Exercise Science, Provo, UT, United States" ;
#     foaf:name "Brodie M." .
#
# kg_sdm:Brodzik_M_J_ a kg_sdm:Author ;
#     kg_sdm:school " Jacobs School of Engineering, Univ. of California, San Diego, 9500 Gilman Dr., San Deigo, CA  92093-0403, United States" ;
#     foaf:name "Brodzik M.J." .
#
# kg_sdm:Bronson_P_G_ a kg_sdm:Reviewers ;
#     kg_sdm:school " US Bureau of Reclamation, United States" ;
#     foaf:name "Bronson P.G." .
#
# kg_sdm:Brown_D_M_ a kg_sdm:Author ;
#     kg_sdm:school " Instituto de Telecomunicacoes, Department of Electrical and Computer Engineering, University of Coimbra, Portugal" ;
#     foaf:name "Brown D.M." .
#
# kg_sdm:Brown_N_ a kg_sdm:Author ;
#     kg_sdm:school "Purdue University, West Lafayette, United States" ;
#     foaf:name "Brown N." .
#
# kg_sdm:Brown_O_ a kg_sdm:Author ;
#     kg_sdm:school " Air Force Research Laboratory, Wright-Patterson Air Force BaseOH  45433, United States" ;
#     foaf:name "Brown O." .
#
# kg_sdm:Brown_T_ a kg_sdm:Chair,
#         kg_sdm:Reviewers ;
#     kg_sdm:school " School of Sustainable Engineering and the Built Environment, Prof. and Sunstate Department of Construction Management and Engineering, Arizona State Univ., P.O. Box 873005, Tempe, AZ  85287-3005, United States",
#         "Compliant Mechanisms Laboratory, Department of Mechanical Engineering, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Brown T." .
#
# kg_sdm:Brownlee_B_J_ a kg_sdm:Chair ;
#     kg_sdm:school "Dept. of Electrical and Computer Eng., Brigham Young University, United States" ;
#     foaf:name "Brownlee B.J." .
#
# kg_sdm:Broyles_Z_ a kg_sdm:Author ;
#     kg_sdm:school " Bayer CropScience LP, Research Triangle ParkNC, United States" ;
#     foaf:name "Broyles Z." .
#
# kg_sdm:Bruening_D_ a kg_sdm:Author ;
#     kg_sdm:school " Woodbury School of Business, Utah Valley University, Orem, UT, United States" ;
#     foaf:name "Bruening D." .
#
# kg_sdm:Brunhaver_J_ a kg_sdm:Author ;
#     kg_sdm:school "College of Engineering, South China Agricultural University, Guangzhou, China" ;
#     foaf:name "Brunhaver J." .
#
# kg_sdm:Bryan_C_R_ a kg_sdm:Author ;
#     kg_sdm:school "Roseman University of Health Sciences, College of Dental Medicine, South Jordan, UT  84095, United States" ;
#     foaf:name "Bryan C.R." .
#
# kg_sdm:Bucki_R_ a kg_sdm:Author ;
#     kg_sdm:school "School of Information Engineering, Henan University of Science and Technology, Luoyang City, Henan Province, 471000, China" ;
#     foaf:name "Bucki R." .
#
# kg_sdm:Buie_M_W_ a kg_sdm:Editor ;
#     kg_sdm:school "CubiScan, Farmington, UT  84025, United States" ;
#     foaf:name "Buie M.W." .
#
# kg_sdm:Bull_D_J_ a kg_sdm:Author ;
#     kg_sdm:school "Los Alamos National Laboratory, United States" ;
#     foaf:name "Bull D.J." .
#
# kg_sdm:Bundy_B_C_ a kg_sdm:Author ;
#     kg_sdm:school "Department of Electrical Engineering and Computer Science, Washington State University, Pullman, WA  99164, United States" ;
#     foaf:name "Bundy B.C." .
#
# kg_sdm:Bunimovich_L_ a kg_sdm:Author ;
#     kg_sdm:school " U.S. Naval Research Laboratory, Washington, D.C  20375, United States" ;
#     foaf:name "Bunimovich L." .
#
# kg_sdm:Bunnell_S_ a kg_sdm:Author ;
#     kg_sdm:school "School of Communications, Brigham Young University, United States" ;
#     foaf:name "Bunnell S." .
#
# kg_sdm:Burdette_M_J_ a kg_sdm:Chair ;
#     kg_sdm:school " School of Mechanical Engineering, Purdue University, 585 Purdue Mall, West Lafayette, IN  47907, United States" ;
#     foaf:name "Burdette M.J." .
#
# kg_sdm:Burgett_J_M_ a kg_sdm:Chair ;
#     kg_sdm:school " Vehicle Technologies, Department of Energy, Washington, DC, United States" ;
#     foaf:name "Burgett J.M." .
#
# kg_sdm:Burrow_D_ a kg_sdm:Editor ;
#     kg_sdm:school "Department of mechanical engineering, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Burrow D." .
#
# kg_sdm:Butler_J_J_ a kg_sdm:Author ;
#     kg_sdm:school " Chemistry and Biochemistry Department, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Butler J.J." .
#
# kg_sdm:Cabas_A_ a kg_sdm:Author ;
#     kg_sdm:school " Centre de Mise en Forme des Materiaux, Mines ParisTech, Sophia-Antipolis, 06904, France" ;
#     foaf:name "Cabas A." .
#
# kg_sdm:Caglar_B_ a kg_sdm:Author ;
#     kg_sdm:school " Departments of Petroleum and Chemical Engineering, University of Wyoming, Laramie, WY  82071, United States" ;
#     foaf:name "Caglar B." .
#
# kg_sdm:Caglar_H_ a kg_sdm:Author ;
#     kg_sdm:school " School of Resources and Environment Engineering, East China University of Science and Technology, Shanghai, 200237, China" ;
#     foaf:name "Caglar H." .
#
# kg_sdm:Call_M_S_ a kg_sdm:Editor ;
#     kg_sdm:school " CKR Engineers, 1295 N State St., Orem, UT  84057, United States" ;
#     foaf:name "Call M.S." .
#
# kg_sdm:Callahan_C_ a kg_sdm:Author ;
#     kg_sdm:school " School of Engineering, University of California, Santa Cruz, CA, United States" ;
#     foaf:name "Callahan C." .
#
# kg_sdm:Calton_M_F_ a kg_sdm:Author ;
#     kg_sdm:school "Departament d′Enginyeria Mecànica, Universitat Rovira i Virgili, Av. Països Catalans, 26, Tarragona, 43007, Spain" ;
#     foaf:name "Calton M.F." .
#
# kg_sdm:Calve_S_ a kg_sdm:Author ;
#     kg_sdm:school "Compliant Mechanisms Laboratory, Department of Mechanical Engineering, Brigham Young University, Provo, UT, United States" ;
#     foaf:name "Calve S." .
#
# kg_sdm:Calvin_J_J_ a kg_sdm:Reviewers ;
#     kg_sdm:school " U.S. Army Corps of Engineers, Kansas City District, 601 E. 12th -Rfsti, Kansas City, MO  64106, United States" ;
#     foaf:name "Calvin J.J." .
#
# kg_sdm:Calvopiña_D_G_ a kg_sdm:Author ;
#     kg_sdm:school " NSF Center for Space, High-Performance, and Resilient Computing (SHREC), Provo, UT  84602, United States" ;
#     foaf:name "Calvopiña D.G." .
#
# kg_sdm:Camacho_J_S_ a kg_sdm:Author ;
#     kg_sdm:school " Northern Arizona University, Department of Physics and Astronomy, Flagstaff, AZ, United States" ;
#     foaf:name "Camacho J.S." .
#
# kg_sdm:Camacho_R_ a kg_sdm:Author ;
#     kg_sdm:school "Center for Friction Stir Processing, Advanced Materials and Manufacturing Processes Institute, University of North Texas, Denton, TX  76203, United States" ;
#     foaf:name "Camacho R." .
#
# kg_sdm:Camacho_R_M_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Materials Mechanics & Tribology, Sandia National Laboratories, PO Box 5800, Albuquerque, NM  87185, United States" ;
#     foaf:name "Camacho R.M." .
#
# kg_sdm:Cameron_J_ a kg_sdm:Reviewers ;
#     kg_sdm:school " US Army Research Laboratory, United States" ;
#     foaf:name "Cameron J." .
#
# kg_sdm:Campbell_B_D_ a kg_sdm:Editor ;
#     kg_sdm:school "Department of Construction Science, College of Architecture, Texas A and M University, College Station, TX, United States" ;
#     foaf:name "Campbell B.D." .
#
# kg_sdm:Campbell_B_J_ a kg_sdm:Author ;
#     kg_sdm:school " Faculty of Technical Sciences, Electr. and Com. Eng. Novi Sad, Serbia Academy of Engineering Sciences of Serbia, Dept. of Power, Serbia" ;
#     foaf:name "Campbell B.J." .
#
# kg_sdm:Candia_G_ a kg_sdm:Author ;
#     kg_sdm:school " University of California, Electrical and Computer Engineering Department, Santa Cruz, CA, United States" ;
#     foaf:name "Candia G." .
#
# kg_sdm:Canizales_K_A_ a kg_sdm:Author ;
#     kg_sdm:school " Oak Ridge National Laboratoy, Oak Ride, TN, United States" ;
#     foaf:name "Canizales K.A." .
#
# kg_sdm:Cannon_M_J_ a kg_sdm:Author ;
#     kg_sdm:school "Brigham Young University, NSF Center for Space, High-Performance, and Resilient Computing (SHREC), Provo, UT  84602, United States" ;
#     foaf:name "Cannon M.J." .
#
# kg_sdm:Cannon_S_ a kg_sdm:Author ;
#     kg_sdm:school " Brigham Young University, Department of Electrical and Computer Engineering, Provo, UT  84602, United States" ;
#     foaf:name "Cannon S." .
#
# kg_sdm:Cao_J_ a kg_sdm:Author ;
#     kg_sdm:school " Composites Manufacturing & Simulation Center, Purdue University, United States" ;
#     foaf:name "Cao J." .
#
# kg_sdm:Cao_Q_ a kg_sdm:Author ;
#     kg_sdm:school "Chemistry and Biochemistry, College of Physical and Mathematical Sciences, Brigham Young University, Provo, UT, United States" ;
#     foaf:name "Cao Q." .
#
# kg_sdm:Capotondi_F_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Mechanical and Aerospace Engineering, University of California San Diego, La Jolla, CA, United States" ;
#     foaf:name "Capotondi F." .
#
# kg_sdm:Carilho_M_ a kg_sdm:Reviewers ;
#     kg_sdm:school "Department of Structures and Civil Engineering, Federal University of Santa Maria, Brazil" ;
#     foaf:name "Carilho M." .
#
# kg_sdm:Carlson_B_ a kg_sdm:Author ;
#     kg_sdm:school "DECC, UFSM, Santa Maria, 97105-900, Brazil" ;
#     foaf:name "Carlson B." .
#
# kg_sdm:Carlson_S_ a kg_sdm:Author ;
#     kg_sdm:school "Chemical Engineering Department, Brigham Young University, Provo, UT, United States" ;
#     foaf:name "Carlson S." .
#
# kg_sdm:Carneiro_A_ a kg_sdm:Reviewers ;
#     kg_sdm:school " General Motors LLC, United States" ;
#     foaf:name "Carneiro A." .
#
# kg_sdm:Carpenter_J_P_ a kg_sdm:Editor ;
#     kg_sdm:school "NSF, Center for High-Performance Reconfigurable Computing (CHREC), Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Carpenter J.P." .
#
# kg_sdm:Carr_A_ a kg_sdm:Reviewers ;
#     kg_sdm:school " International Society of Sustainability Professionals, 1936 Fifth Ave., Pittsburgh, PA  15219, United States" ;
#     foaf:name "Carr A." .
#
# kg_sdm:Carreira_M_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Microbiology and Molecular Biology, Brigham Young University, Provo, UT, United States" ;
#     foaf:name "Carreira M." .
#
# kg_sdm:Carroll_J_D_ a kg_sdm:Author ;
#     kg_sdm:school " Dept. of Biomedical Engineering, Rochester Institute of Technology, Rochester, NY, United States" ;
#     foaf:name "Carroll J.D." .
#
# kg_sdm:Carsley_J_E_ a kg_sdm:Editor ;
#     kg_sdm:school " Applied Geotechnical Engineering Consultants, 600 West Sandy Parkway, Sandy, UT  84070, United States" ;
#     foaf:name "Carsley J.E." .
#
# kg_sdm:Carver_V_ a kg_sdm:Reviewers ;
#     kg_sdm:school "School of Teacher Education and Leadership, Utah State University, Logan, UT, United States" ;
#     foaf:name "Carver V." .
#
# kg_sdm:Casbeer_D_W_ a kg_sdm:Author ;
#     kg_sdm:school " Chemical Engineering Department, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Casbeer D.W." .
#
# kg_sdm:Cattaneo_A_ a kg_sdm:Author ;
#     kg_sdm:school " State Key Laboratory for Manufacturing Systems Engineering, Xi'an Jiaotong University, Xi'an, 710049, China" ;
#     foaf:name "Cattaneo A." .
#
# kg_sdm:Cayeux_E_ a kg_sdm:Reviewers ;
#     kg_sdm:school " MRC Centre for Neuropsychiatric Genetics and Genomics, Division of Psychological Medicine and Clinical Neurosciences, Cardiff University, Cardiff, United Kingdom" ;
#     foaf:name "Cayeux E." .
#
# kg_sdm:Cazzaniga_C_ a kg_sdm:Reviewers ;
#     kg_sdm:school " American Water Works Association, Transportation Research Board Committee on Culverts and Hydraulic Structures, United States" ;
#     foaf:name "Cazzaniga C." .
#
# kg_sdm:Chahal_J_S_ a kg_sdm:Chair ;
#     kg_sdm:school " L-3 Communications, Communication Systems - West, Salt Lake City, UT  84118, United States" ;
#     foaf:name "Chahal J.S." .
#
# kg_sdm:Chalfant_T_ a kg_sdm:Chair ;
#     kg_sdm:school "Department of Mechanical Engineering, Brigham Young University, 435B CTB, Provo, UT  84602, United States" ;
#     foaf:name "Chalfant T." .
#
# kg_sdm:Chamberlin_R_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Polymer Materials and Plastics Engineering, Technische Universität Clausthal, Germany" ;
#     foaf:name "Chamberlin R." .
#
# kg_sdm:Chambers_C_ a kg_sdm:Author ;
#     kg_sdm:school " Exponent, Civil Engineering Practice, Oakland, CA, United States" ;
#     foaf:name "Chambers C." .
#
# kg_sdm:Chan_E_K_L_ a kg_sdm:Chair ;
#     kg_sdm:school " Colorado School of Mines, United States" ;
#     foaf:name "Chan E.K.L." .
#
# kg_sdm:Chanda_A_ a kg_sdm:Editor ;
#     kg_sdm:school " ISISE, University of Minho, Department of Civil Engineering, Portugal" ;
#     foaf:name "Chanda A." .
#
# kg_sdm:Chang_J_S_ a kg_sdm:Author ;
#     kg_sdm:school "Center for Materials Genomics, Duke University, Durham, NC  27708, United States" ;
#     foaf:name "Chang J.S." .
#
# kg_sdm:Chang_M_-C_F_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Civil and Environmental Engineering, Brigham Young University, Utah, United States" ;
#     foaf:name "Chang M.-C.F." .
#
# kg_sdm:Chapman_S_C_ a kg_sdm:Author ;
#     kg_sdm:school "University of Illinois at Urbana-Champaign, United States" ;
#     foaf:name "Chapman S.C." .
#
# kg_sdm:Charles_S_K_ a kg_sdm:Author ;
#     kg_sdm:school " Hitachi-Technologies America Inc., Clarksburg, MD  20871, United States" ;
#     foaf:name "Charles S.K." .
#
# kg_sdm:Chartrand_N_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Physics, University of Colorado, Boulder, CO  80309, United States" ;
#     foaf:name "Chartrand N." .
#
# kg_sdm:Chatterjee_S_ a kg_sdm:Author,
#         kg_sdm:Reviewers ;
#     kg_sdm:school " Instituto de Telecomunicacões, Department of Electrical and Computer Engineering, University of Coimbra, Portugal",
#         "Brigham Young University, S-389 ESC, Provo, UT  84601, United States" ;
#     foaf:name "Chatterjee S." .
#
# kg_sdm:Chau_V_ a kg_sdm:Reviewers ;
#     kg_sdm:school " University of Dayton, Dayton, OH, United States" ;
#     foaf:name "Chau V." .
#
# kg_sdm:Chelladurai_I_ a kg_sdm:Author ;
#     kg_sdm:school "Dept. of Physics and Astronomy, Brigham Young UniversityUT, United States" ;
#     foaf:name "Chelladurai I." .
#
# kg_sdm:Chelton_D_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Departments of Neurology, Psychiatry, Radiology, Engineering, Pediatrics and Ophthalmology, University of Southern CaliforniaCA, United States" ;
#     foaf:name "Chelton D." .
#
# kg_sdm:Chen_C_-H_ a kg_sdm:Author ;
#     kg_sdm:school " Elettra-Sincrotrone Trieste S.C.pA., S.S. 14km 163 5 in Area Science Park Basovizza, Trieste, 34149, Italy" ;
#     foaf:name "Chen C.-H." .
#
# kg_sdm:Chen_G_ a kg_sdm:Author,
#         kg_sdm:Editor ;
#     kg_sdm:school " C2MA, IMT Mines Ales, Univ. Montpellier, Ales, France",
#         " Luxembourg Centre for Systems Biomedicine, University of Luxembourg, Luxembourg, L-4365, Luxembourg" ;
#     foaf:name "Chen G." .
#
# kg_sdm:Chen_J_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Uppsala University, Sweden" ;
#     foaf:name "Chen J." .
#
# kg_sdm:Chen_K_ a kg_sdm:Author ;
#     kg_sdm:school " University of California, Santa Cruz, School of Engineering, 1156 High Street, Santa Cruz, CA  95064, United States" ;
#     foaf:name "Chen K." .
#
# kg_sdm:Chen_L_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Mechanical Engineering, KOÇ University, Turkey" ;
#     foaf:name "Chen L." .
#
# kg_sdm:Chen_X_ a kg_sdm:Author ;
#     kg_sdm:school " Institute of Geological Sciences, Planetary Sciences and Remote Sensing, Freie Universität Berlin, Germany" ;
#     foaf:name "Chen X." .
#
# kg_sdm:Chen_Y_-F_ a kg_sdm:Author ;
#     kg_sdm:school " Department of Computer Engineering, Faculty of Engineering, Çukurova University, Adana, Turkey" ;
#     foaf:name "Chen Y.-F." .
#
# kg_sdm:Cheng_L_ a kg_sdm:Reviewers ;
#     kg_sdm:school " Ocean Flow International, 2100 West Loop South Suite 500, Houston, TX  77027, United States" ;
#     foaf:name "Cheng L." .
#
# kg_sdm:Cheung_K_-M_ a kg_sdm:Author ;
#     kg_sdm:school " Texas Center for Superconductivity at UH (TcSUH), University of Houston, Houston, TX  77204, United States" ;
#     foaf:name "Cheung K.-M." .
#
# kg_sdm:Chiang_S_-H_W_ a kg_sdm:Author ;
#     kg_sdm:school "Brigham Young University, Computer Science Department, Provo, United States" ;
#     foaf:name "Chiang S.-H.W." .
#
# kg_sdm:Childs_C_ a kg_sdm:Author ;
#     kg_sdm:school "National University of Mexico, Mexico City, Mexico" ;
#     foaf:name "Childs C." .
#
# kg_sdm:Chiminelli_A_ a kg_sdm:Author ;
#     kg_sdm:school " School of Chemical and Environmental Engineering, China University of Mining and Technology, Beijing, 100080, China" ;
#     foaf:name "Chiminelli A." .
#
# kg_sdm:Choi_G_ a kg_sdm:Chair ;
#     kg_sdm:school " Department of Statistics, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Choi G." .
#
# kg_sdm:Chou_Y_ a kg_sdm:Author ;
#     kg_sdm:school " Laboratory of Composite Materials and Adaptive Structures, ETH Zurich, Switzerland",
#         "Statistical Sciences Group, CCS-6, Los Alamos National Laboratory, Santa Fe, NM, United States" ;
#     foaf:name "Chou Y." .
#
# kg_sdm:Choudhury_D_ a kg_sdm:Chair,
#         kg_sdm:Editor ;
#     kg_sdm:school " Department of Architecture, Building and Planning, Eindhoven University, Netherlands" ;
#     foaf:name "Choudhury D." .
#
# kg_sdm:Chowdhury_S_ a kg_sdm:Author ;
#     kg_sdm:school " Department for Power, Electronic and Communication Engineering, Faculty of Technical Sciences, University of Novi Sad, Novi Sad, 21000, Serbia" ;
#     foaf:name "Chowdhury S." .
#
# kg_sdm:Chrisey_L_A_ a kg_sdm:Reviewers ;
#     kg_sdm:school "Ira A. Fulton College of Engineering and Technology, Brigham Young Univ., Provo, UT  84602, United States" ;
#     foaf:name "Chrisey L.A." .
#
# kg_sdm:Christensen_C_ a kg_sdm:Editor ;
#     kg_sdm:school " Information and Decision Algorithms Laboratories and the Computer Science Department, Brigham Young University, Provo, UT  84602, United States" ;
#     foaf:name "Christensen C." .
#
# kg_sdm:Christensen_J_B_ a kg_sdm:Chair ;
#     kg_sdm:school " Institute for Computational Engineering and Sciences, The University of Texas at Austin, 201 East 24th Street, C0200, Austin, TX  78712-1229, United States" ;
#     foaf:name "Christensen J.B." .
#
# kg_sdm:Christensen_J_E_ a kg_sdm:Author ;
#     kg_sdm:school " Rockwell Collins, Cedar Rapids, IA  52498, United States" ;
#     foaf:name "Christensen J.E." .
#
# kg_sdm:Christensen_K_A_ a kg_sdm:Author ;
#     kg_sdm:school " University of Houston Texas, 7000 Fannin St, Houston, TX, United States" ;
#     foaf:name "Christensen K.A." .
#
# kg_sdm:Christie_S_ a kg_sdm:Author ;
#     kg_sdm:school " Dept. of Civil Engineering, São Paulo State Univ., Alameda Bahia 550, Ilha Solteira, São Paulo, 15385-000, Brazil" ;
#     foaf:name "Christie S." .
#
# kg_sdm:Chu_H_ a kg_sdm:Author ;
#     kg_sdm:school " Concepts NREC, 217 Billings Farm Road, White River Junction, VT  05001, United States" ;
#     foaf:name "Chu H." .
#
# ...
#
# <http://kg_sdm.org/venue/Three_dimensional_microscopic_light_field_particle_image_velocimetry> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Three_dimensional_microscopic_light_field_particle_image_velocimetry" .
#
# <http://kg_sdm.org/venue/Three_way_spectral_decompositions_of_high_performance_military_aircraft_noise> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "Three_way_spectral_decompositions_of_high_performance_military_aircraft_noise" .
#
# <http://kg_sdm.org/venue/Time_reversal_techniques> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Time_reversal_techniques" .
#
# <http://kg_sdm.org/venue/Total_hemispherical_apparent_radiative_properties_of_the_infinite_V_Groove_with_diffuse_reflection> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Total_hemispherical_apparent_radiative_properties_of_the_infinite_V_Groove_with_diffuse_reflection" .
#
# <http://kg_sdm.org/venue/Total_hemispherical_apparent_radiative_properties_of_the_infinite_V_groove_with_specular_reflection> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Total_hemispherical_apparent_radiative_properties_of_the_infinite_V_groove_with_specular_reflection" .
#
# <http://kg_sdm.org/venue/Toward_a_Universal_Social_Impact_Metric_for_Engineered_Products_That_Alleviate_Poverty> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Toward_a_Universal_Social_Impact_Metric_for_Engineered_Products_That_Alleviate_Poverty" .
#
# <http://kg_sdm.org/venue/Toward_quantitative_characterization_of_essential_tremor_for_future_tremor_suppression> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Toward_quantitative_characterization_of_essential_tremor_for_future_tremor_suppression" .
#
# <http://kg_sdm.org/venue/Towards_a_universal_social_impact_metric_for_engineered_products_that_alleviate_poverty> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Towards_a_universal_social_impact_metric_for_engineered_products_that_alleviate_poverty" .
#
# <http://kg_sdm.org/venue/Tracking_joint_angles_during_whole_arm_movements_using_electromagnetic_sensors> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Tracking_joint_angles_during_whole_arm_movements_using_electromagnetic_sensors" .
#
# <http://kg_sdm.org/venue/Tracking_multiple_vehicles_constrained_to_a_road_network_from_a_uav_with_sparse_visual_measurements> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "Tracking_multiple_vehicles_constrained_to_a_road_network_from_a_uav_with_sparse_visual_measurements" .
#
# <http://kg_sdm.org/venue/Transitioning_a_manufacturing_systems_engineering_course_to_student_centered_learning> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Transitioning_a_manufacturing_systems_engineering_course_to_student_centered_learning" .
#
# <http://kg_sdm.org/venue/Transparency__Transitioning_From_Human–Machine_Systems_to_Human_Swarm_Systems> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Transparency__Transitioning_From_Human–Machine_Systems_to_Human_Swarm_Systems" .
#
# <http://kg_sdm.org/venue/Traverses_for_the_ISECG_GER_design_reference_mission_for_humans_on_the_lunar_surface> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "Traverses_for_the_ISECG_GER_design_reference_mission_for_humans_on_the_lunar_surface" .
#
# <http://kg_sdm.org/venue/TrustBase__An_architecture_to_repair_and_strengthen_certificate_based_authentication> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "TrustBase__An_architecture_to_repair_and_strengthen_certificate_based_authentication" .
#
# <http://kg_sdm.org/venue/Tuning_Ferritin_s_band_gap_through_mixed_metal_oxide_nanoparticle_formation> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Tuning_Ferritin_s_band_gap_through_mixed_metal_oxide_nanoparticle_formation" .
#
# <http://kg_sdm.org/venue/Turbulence_modulation_in_particle_laden_stationary_homogeneous_isotropic_turbulence_using_one_dimensional_turbulence> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Turbulence_modulation_in_particle_laden_stationary_homogeneous_isotropic_turbulence_using_one_dimensional_turbulence" .
#
# <http://kg_sdm.org/venue/Turning_Disaster_into_Knowledge__Geotechnical_Aspects_of_the_2018_Mw_7_1_Anchorage_Alaska_Earthquake> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Turning_Disaster_into_Knowledge__Geotechnical_Aspects_of_the_2018_Mw_7_1_Anchorage_Alaska_Earthquake" .
#
# <http://kg_sdm.org/venue/Turning_depths__Evanescent_to_propagating_wave_kinetic_energy_density> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "Turning_depths__Evanescent_to_propagating_wave_kinetic_energy_density" .
#
# <http://kg_sdm.org/venue/Tutorial_on_interpreting_x_ray_photoelectron_spectroscopy_survey_spectra__Questions_and_answers_on_spectra_from_the_atomic_layer_deposition_of_Al2O3_on_silicon> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "Tutorial_on_interpreting_x_ray_photoelectron_spectroscopy_survey_spectra__Questions_and_answers_on_spectra_from_the_atomic_layer_deposition_of_Al2O3_on_silicon" .
#
# <http://kg_sdm.org/venue/Twining_and_dynamic_recrystallization_in_austenitic_Alloy_718_during_friction_welding> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Twining_and_dynamic_recrystallization_in_austenitic_Alloy_718_during_friction_welding" .
#
# <http://kg_sdm.org/venue/Two_phase_flow_pressure_drop_in_superhydrophobic_channels> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Two_phase_flow_pressure_drop_in_superhydrophobic_channels" .
#
# <http://kg_sdm.org/venue/Understanding_engineering_and_technology_student_perceptions__Barriers_to_study_abroad_participation> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Understanding_engineering_and_technology_student_perceptions__Barriers_to_study_abroad_participation" .
#
# <http://kg_sdm.org/venue/Understanding_the_Impact_of_Quantization__Accuracy__and_Radiation_on_the_Reliability_of_Convolutional_Neural_Networks_on_FPGAs> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Understanding_the_Impact_of_Quantization__Accuracy__and_Radiation_on_the_Reliability_of_Convolutional_Neural_Networks_on_FPGAs" .
#
# <http://kg_sdm.org/venue/Unification_of_signal_models_for_soqpsk> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Unification_of_signal_models_for_soqpsk" .
#
# <http://kg_sdm.org/venue/Universal_airfoil_parametrization_using_B_splines> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Universal_airfoil_parametrization_using_B_splines" .
#
# <http://kg_sdm.org/venue/Unpacking_the_Mathematics_of_Modeling_Origami_Folding_Transformations_with Quaternions> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Unpacking_the_Mathematics_of_Modeling_Origami_Folding_Transformations_with Quaternions" .
#
# <http://kg_sdm.org/venue/Use_of_Hi_resolution_data_for_evaluating_accuracy_of_traffic_volume_counts_collected_by_microwave_sensors> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Use_of_Hi_resolution_data_for_evaluating_accuracy_of_traffic_volume_counts_collected_by_microwave_sensors" .
#
# <http://kg_sdm.org/venue/Use_of_Personality_Profile_Assessments_in_the_U_S__Commercial_Construction_Industry> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Use_of_Personality_Profile_Assessments_in_the_U_S__Commercial_Construction_Industry" .
#
# <http://kg_sdm.org/venue/User_attitudes_toward_the_inspection_of_encrypted_traffic> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "User_attitudes_toward_the_inspection_of_encrypted_traffic" .
#
# <http://kg_sdm.org/venue/Using_Cyclic_Quadrilaterals_to_Design_Cylindrical_Developable_Mechanisms> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Using_Cyclic_Quadrilaterals_to_Design_Cylindrical_Developable_Mechanisms" .
#
# <http://kg_sdm.org/venue/Using_Partial_Duplication_with_Compare_to_Detect_Radiation_Induced_Failure_in_a_Commercial_FPGA_Based_Networking_System> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Using_Partial_Duplication_with_Compare_to_Detect_Radiation_Induced_Failure_in_a_Commercial_FPGA_Based_Networking_System" .
#
# <http://kg_sdm.org/venue/Using_a_Deep_Learning_Model__Content_Features__and_Author_Metadata_to_Recommend_Research_Papers> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Using_a_Deep_Learning_Model__Content_Features__and_Author_Metadata_to_Recommend_Research_Papers" .
#
# <http://kg_sdm.org/venue/Using_a_Product_s_Sustainability_Space_as_a_Design_Exploration_Tool> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "Using_a_Product_s_Sustainability_Space_as_a_Design_Exploration_Tool" .
#
# <http://kg_sdm.org/venue/Using_case_method_pedagogy_to_facilitate_audience_awareness> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "Using_case_method_pedagogy_to_facilitate_audience_awareness" .
#
# <http://kg_sdm.org/venue/Using_ellipsometry_and_X_ray_photoelectron_spectroscopy_for_real_time_monitoring_of_the_oxidation_of_aluminum_mirrors_protected_by_ultrathin_MgF2_layers> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "Using_ellipsometry_and_X_ray_photoelectron_spectroscopy_for_real_time_monitoring_of_the_oxidation_of_aluminum_mirrors_protected_by_ultrathin_MgF2_layers" .
#
# <http://kg_sdm.org/venue/Using_instagram_to_increase_student_engagement_with_design_history> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Using_instagram_to_increase_student_engagement_with_design_history" .
#
# <http://kg_sdm.org/venue/Using_local_invasive_species_and_flora_to_manufacture_collagen_based_biodegradable_plastic_tableware> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Using_local_invasive_species_and_flora_to_manufacture_collagen_based_biodegradable_plastic_tableware" .
#
# <http://kg_sdm.org/venue/Using_non_destructive_testing_to_predict_bending_modulus_of_carbon_infiltrated_carbon_nanotubes> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Using_non_destructive_testing_to_predict_bending_modulus_of_carbon_infiltrated_carbon_nanotubes" .
#
# <http://kg_sdm.org/venue/Using_physical_and_functional_comparisons_to_assure_3rd_party_IP_for_modern_FPGAs> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "Using_physical_and_functional_comparisons_to_assure_3rd_party_IP_for_modern_FPGAs" .
#
# <http://kg_sdm.org/venue/Using_tripartite_graphs_to_make_long_tail_recommendations> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Using_tripartite_graphs_to_make_long_tail_recommendations" .
#
# <http://kg_sdm.org/venue/Using_vegetation_management_and_LiDAR_derived_tree_height_data_to_improve_outage_predictions_for_electric_utilities> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Using_vegetation_management_and_LiDAR_derived_tree_height_data_to_improve_outage_predictions_for_electric_utilities" .
#
# <http://kg_sdm.org/venue/Validated_Lateral_Seismic_Force_Displacement_Backbone_Curves_for_High_Speed_Rail_Bridge_Abutments> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Validated_Lateral_Seismic_Force_Displacement_Backbone_Curves_for_High_Speed_Rail_Bridge_Abutments" .
#
# <http://kg_sdm.org/venue/Variable_stiffness_adaptation_to_mitigate_system_failure_in_inflatable_robots> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Variable_stiffness_adaptation_to_mitigate_system_failure_in_inflatable_robots" .
#
# <http://kg_sdm.org/venue/Vertical_electrical_impedance_testing_of_a_concrete_bridge_deck_using_a_rolling_probe> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Vertical_electrical_impedance_testing_of_a_concrete_bridge_deck_using_a_rolling_probe" .
#
# <http://kg_sdm.org/venue/Village_Drill__A_Case_Study_in_Engineering_for_Global_Development_with_Five_Years_of_Data_Post_Market_Introduction> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Village_Drill__A_Case_Study_in_Engineering_for_Global_Development_with_Five_Years_of_Data_Post_Market_Introduction" .
#
# <http://kg_sdm.org/venue/Visio_acoustic_data_fusion_for_structural_health_monitoring_applications> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Visio_acoustic_data_fusion_for_structural_health_monitoring_applications" .
#
# <http://kg_sdm.org/venue/Visual_Multiple_Target_Tracking_from_a_Descending_Aerial_Platform> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Visual_Multiple_Target_Tracking_from_a_Descending_Aerial_Platform" .
#
# <http://kg_sdm.org/venue/Visual_servoing_for_multirotor_precision_landing_in_daylight_and_after_dark_conditions> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "Visual_servoing_for_multirotor_precision_landing_in_daylight_and_after_dark_conditions" .
#
# <http://kg_sdm.org/venue/Visual_servoing_with_feed_forward_for_precision_shipboard_landing_of_an_autonomous_multirotor> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "Visual_servoing_with_feed_forward_for_precision_shipboard_landing_of_an_autonomous_multirotor" .
#
# <http://kg_sdm.org/venue/Volume_and_frequency_independent_spreading_of_droplets_driven_by_ultrasonic_surface_vibration> a kg_sdm:Journal ;
#     kg_sdm:venue_title "Volume_and_frequency_independent_spreading_of_droplets_driven_by_ultrasonic_surface_vibration" .
#
# <http://kg_sdm.org/venue/Volumetric_display_by_movement_of_particles_trapped_in_a_laser_via_photophoresis> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Volumetric_display_by_movement_of_particles_trapped_in_a_laser_via_photophoresis" .
#
# <http://kg_sdm.org/venue/Volumetric_displays> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Volumetric_displays" .
#
# <http://kg_sdm.org/venue/Water_entry_of_deformable_spheres> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Water_entry_of_deformable_spheres" .
#
# <http://kg_sdm.org/venue/Water_main_criticality_scoring_and_GIS_centric_risk_mitigation__Applying_GIS_spatial_analysis_tools_and_apps_for_greater_insight_for_high_risk_underground_infrastructure> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Water_main_criticality_scoring_and_GIS_centric_risk_mitigation__Applying_GIS_spatial_analysis_tools_and_apps_for_greater_insight_for_high_risk_underground_infrastructure" .
#
# <http://kg_sdm.org/venue/Water_supply_damage_caused_by_the_2016_Kumamoto_Earthquake> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Water_supply_damage_caused_by_the_2016_Kumamoto_Earthquake" .
#
# <http://kg_sdm.org/venue/Waves_of_destruction_in_the_East_Indies__The_Wichmann_catalogue_of_earthquakes_and_tsunami_in_the_Indonesian_region_from_1538_to_1877> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Waves_of_destruction_in_the_East_Indies__The_Wichmann_catalogue_of_earthquakes_and_tsunami_in_the_Indonesian_region_from_1538_to_1877" .
#
# <http://kg_sdm.org/venue/Weighing_Context_and_Trade_offs__How_suburban_adults_selected_their_online_security_posture> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "Weighing_Context_and_Trade_offs__How_suburban_adults_selected_their_online_security_posture" .
#
# <http://kg_sdm.org/venue/When_do_workarounds_help_or_hurt_patient_outcomes__The_moderating_role_of_operational_failures> a kg_sdm:Journal ;
#     kg_sdm:venue_title "When_do_workarounds_help_or_hurt_patient_outcomes__The_moderating_role_of_operational_failures" .
#
# <http://kg_sdm.org/venue/When_does_a_human_replan__Exploring_intent_based_replanning_in_multi_objective_path_planning> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "When_does_a_human_replan__Exploring_intent_based_replanning_in_multi_objective_path_planning" .
#
# <http://kg_sdm.org/venue/When_is_a_tree_really_a_truck__Exploring_mental_models_of_encryption> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "When_is_a_tree_really_a_truck__Exploring_mental_models_of_encryption" .
#
# <http://kg_sdm.org/venue/When_official_systems_overload__A_framework_for_finding_social_media_calls_for_help_during_evacuations> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "When_official_systems_overload__A_framework_for_finding_social_media_calls_for_help_during_evacuations" .
#
# <http://kg_sdm.org/venue/Whole_genome_phylogenetic_tree_reconstruction_using_colored_de_bruijn_graphs> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Whole_genome_phylogenetic_tree_reconstruction_using_colored_de_bruijn_graphs" .
#
# <http://kg_sdm.org/venue/Zipper_Tube_Reinforcement_to_Mitigate_Flexible_Shaft_Buckling> a kg_sdm:Symposium ;
#     kg_sdm:venue_title "Zipper_Tube_Reinforcement_to_Mitigate_Flexible_Shaft_Buckling" .
#
# <http://kg_sdm.org/venue/“Something_isn_t_secure__but_I_m_not_sure_how_that_translates_into_a_problem”__Promoting_autonomy_by_designing_for_understanding_in_Signal> a kg_sdm:Workshop ;
#     kg_sdm:venue_title "“Something_isn_t_secure__but_I_m_not_sure_how_that_translates_into_a_problem”__Promoting_autonomy_by_designing_for_understanding_in_Signal" .
