# %%
# import libraries
from rdflib import Graph,Literal,RDF,URIRef
from rdflib.namespace import FOAF,XSD,RDFS
from rdflib import Namespace
import pandas as pd
import string
import random
import numpy as np

# ignore the warning
import warnings
warnings.filterwarnings('ignore')

# %%
# Initialize Graph
g = Graph()

# %% [markdown]
# # Supporting Functions

# %%
KG_SDM = Namespace("http://kg_sdm.org/")
g.bind("kg_sdm",KG_SDM)

# %%
def save_rdf_file(g,filename,rdf_format='ttl'):
    g.serialize(filename+'.'+rdf_format,format= rdf_format)

# %%
# we created this parser as there should not be any forbiden characters in the URI
def URLparse(url:str):
    url=url.replace("\'","_").replace("\"","_")
    for i in string.punctuation:
        url = url.replace(i,"_")
    url = url.replace(" ","_")
    return url

# %% [markdown]
# # Schema Design
# * Once we have created the schema and the TBOX, it's time to populate the graph using triples.
# * On the image you can see the schema that we will be following in this ABOX
# * We are showing the process of grouping the data from csv files and adding them to the knowledge graph.
# * The upload will be done in parts, each part uploading a different part of the graph

# %% [markdown]
# ![title](B1_TBOX-Sotiroski_Choudhary.png)

# %% [markdown]
# # ABOX Defination

# %% [markdown]
# ## 1. Person

# %%
people_names = pd.read_csv('data_kg_sdm/authors.csv') # getting all the the people names from the authors file
people_names.rename(columns = {'name':'person_name'}, inplace=True)
people_names.head()
# Out:
#             ID             person_name
# 0  57218202833               Gautam A.
# 1   7004904337           Crandall J.W.
# 2   7005513246           Goodrich M.A.
# 3   6508306234  de Moura Oliveira P.B.
# 4   9277159100          Hedengren J.D.

# %%
# using the bridge table to connect the author with the school / institution
author_school = pd.read_csv('data_kg_sdm/author_belongs_school.csv')
author_school['author_ID'] = author_school['author_ID'].astype(int)
author_school.head()
# Out:
#      author_ID  org_ID
# 0  57218202833       1
# 1   7004904337       1
# 2   7005513246       1
# 3   6508306234       2
# 4   9277159100       3

# %%
# getting the data for each school
schools = pd.read_csv('data_kg_sdm/schools.csv')
schools.rename(columns = {'name':'school_name'}, inplace=True)
schools.head()
# Out:
#    ID                                        school_name
# 0   1  Computer Science Department, Brigham Young Uni...
# 1   2  INESC-TEC Technology and Science, Campus da FE...
# 2   3   Department of Engineering, University of Trás...
# 3   4   Department of Chemical Engineering, Brigham Y...
# 4   5  Task Committee Secretary and Lead Engineer, Op...

# %%
# merging the academics / people in one table with their related school
academics = pd.merge(schools, author_school, left_on='ID', right_on='org_ID')
academics = pd.merge(academics, people_names, left_on='author_ID', right_on='ID')
academics.head()
# Out:
#    ID_x                                        school_name    author_ID  \
# 0     1  Computer Science Department, Brigham Young Uni...  57218202833
# 1     1  Computer Science Department, Brigham Young Uni...   7004904337
# 2     1  Computer Science Department, Brigham Young Uni...   7005513246
# 3     1  Computer Science Department, Brigham Young Uni...  55078951500
# 4     1  Computer Science Department, Brigham Young Uni...  57215280005
#
#    org_ID         ID_y    person_name
# 0       1  57218202833      Gautam A.
# 1       1   7004904337  Crandall J.W.
# 2       1   7005513246  Goodrich M.A.
# 3       1  55078951500    Bodily P.M.
# 4       1  57215280005  Jacobsen A.J.

# %% [markdown]
# * Once we have all the people/academics we want to divide them depending on their role.
# We suppose 60% are Authors, 20% Reviewsrs, 10% Chair and Editor.
#
# * Every variable will hold either the four types of academics which will be used in other parts of the notebook when uploading the triples

# %%
total = len(academics)
nb_auth = int(total * 0.6)
nb_rev = int(total * 0.2)
nb_chair_editor = int(total * 0.1)

# %%
authors = academics.loc[:nb_auth]
reviewers = academics.loc[nb_auth : nb_auth + nb_rev]
chair = academics.loc[nb_auth + nb_rev : nb_auth + nb_rev + nb_chair_editor ]
editor = academics.loc[ nb_auth + nb_rev + nb_chair_editor :nb_auth + nb_rev + nb_chair_editor + nb_chair_editor]

# %%
person_type_list = [authors,reviewers,chair,editor]
person_sub_type_ls = ["Author","Reviewers","Chair","Editor"]

Person = URIRef("http://kg_sdm.org/Person")

for i,person_tp in enumerate(person_type_list):
    # creating the URI for each person type
    preson_sub_type = URIRef(f"http://kg_sdm.org/{person_sub_type_ls[i]}")
    
    for name, school in zip(person_tp['person_name'], person_tp['school_name']):
        # assigning each person a URI
        parsed_name = URLparse(name)
        person_node = URIRef(f"http://kg_sdm.org/Person/{parsed_name}")
        # their literals
        name_lit = Literal(str(name))
        school_lit = Literal(str(school))

        # Connecting the nodes
        # add subclass type
        g.add((person_node, RDF.type, preson_sub_type))
        # add school
        g.add((person_node, KG_SDM.school, school_lit))
        # add name of person
        g.add((person_node, FOAF.name, name_lit))

# %%
# save_rdf_file(g,'person_links','ttl')

# %% [markdown]
# ## 2. Submissions
# In submission we store the articles from an author submitted to a conference

# %% [markdown]
# ### a. Adding Articles(Papers)

# %%
# loading articles
articles = pd.read_csv('data_kg_sdm/articles.csv')

# %%
# The bridge table that connects the articles that an author wrote
author_article = pd.read_csv('data_kg_sdm/author_written_article.csv')
author_article['author_ID'] = author_article['author_ID'].astype(int)
author_article.head()
# Out:
#      author_ID  article_ID
# 0  57218202833           1
# 1   7004904337           1
# 2   7005513246           1
# 3   6508306234           2
# 4   9277159100           2

# %%
paper_type = ['Demo','FullPaper', 'Poster', 'Short']
keywords = ['ML', 'NLP', 'Database', 'Graph']

# %%
# As we don't have some of the data, we are generating the year randomly, 
# the paper type as well as if a paper is accepted or not.
# As we have to label the paper submissions as accepted or rejected, we take the first 500 articles as accepted

articles['year'] = [ random.randint(2000,2022) for i in range(len(articles))]
articles['type'] = [random.choice(paper_type) for i in range(len(articles))]
articles['keyword'] = [random.choice(keywords) for i in range(len(articles))]
articles['accepted'] = ""
articles['accepted'].loc[:500] = True
articles['accepted'].loc[500:] = False

# %%
articles.head()
# Out:
#    ID                                              title     volume  \
# 0   1  Self-assessment of Proficiency of Intelligent ...  1210 AISC
# 1   2  Bridging theory to practice: Feedforward and c...   695 LNEE
# 2   3  Development of sediment management guidelines ...        146
# 3   4  Structural design space exploration using prin...         20
# 4   5  Religion-focused dating apps: A Q methodology ...         55
#
#                                   DOI  year       type   keyword accepted
# 0        10.1007/978-3-030-51758-8_15  2001  FullPaper     Graph     True
# 1         10.1007/978-3-030-58653-9_3  2022       Demo  Database     True
# 2  10.1061/(ASCE)HY.1943-7900.0001822  2020     Poster  Database     True
# 3                   10.1115/1.4047428  2014      Short  Database     True
# 4          10.1016/j.tele.2020.101448  2003     Poster        ML     True

# %%
# only authors are writing the papers
authors.head()
# Out:
#    ID_x                                        school_name    author_ID  \
# 0     1  Computer Science Department, Brigham Young Uni...  57218202833
# 1     1  Computer Science Department, Brigham Young Uni...   7004904337
# 2     1  Computer Science Department, Brigham Young Uni...   7005513246
# 3     1  Computer Science Department, Brigham Young Uni...  55078951500
# 4     1  Computer Science Department, Brigham Young Uni...  57215280005
#
#    org_ID         ID_y    person_name
# 0       1  57218202833      Gautam A.
# 1       1   7004904337  Crandall J.W.
# 2       1   7005513246  Goodrich M.A.
# 3       1  55078951500    Bodily P.M.
# 4       1  57215280005  Jacobsen A.J.

# %%
# joining the authors and articles with the bridge table
article_pub = pd.merge(articles, author_article, left_on='ID', right_on='article_ID')
articles_publishedin = pd.merge(article_pub, authors, left_on='author_ID', right_on='author_ID')
articles_publishedin = articles_publishedin[['title', 'year', 'type', 'keyword', 'accepted', 'person_name', 'school_name']]

# %%
articles_publishedin.head()
# Out:
#                                                title  year       type  \
# 0  Self-assessment of Proficiency of Intelligent ...  2001  FullPaper
# 1  Self-assessment of Proficiency of Intelligent ...  2001  FullPaper
# 2  Moderating operator influence in human-swarm s...  2018       Demo
# 3  Cooperating in long-term relationships with ti...  2022      Short
# 4  Information design in crowdfunding under thres...  2006      Short
#
#     keyword accepted    person_name  \
# 0     Graph     True      Gautam A.
# 1     Graph     True  Crandall J.W.
# 2  Database     True  Crandall J.W.
# 3        ML     True  Crandall J.W.
# 4       NLP    False  Crandall J.W.
#
#                                          school_name
# 0  Computer Science Department, Brigham Young Uni...
# 1  Computer Science Department, Brigham Young Uni...
# 2  Computer Science Department, Brigham Young Uni...
# 3  Computer Science Department, Brigham Young Uni...
# 4  Computer Science Department, Brigham Young Uni...

# %%
for _, article_title, year, paper_type, keyword, accepted, author_name, school_name in articles_publishedin.itertuples():
    # get the author node
    author_node = URIRef(f"http://kg_sdm.org/Person/{URLparse(author_name)}")
    
    # create the submission onde
    submission_node = URIRef(f"http://kg_sdm.org/Submission/{URLparse(article_title)}")
    g.add((submission_node, RDF.type, KG_SDM.Submission))
    
    # author wrote a paper
    g.add((author_node, KG_SDM.writes, submission_node))
    
    # data for submission
    paper_title_lit = Literal(str(article_title))
    paper_year_lit = Literal(int(year))
    g.add((submission_node, KG_SDM.paper_title, paper_title_lit))
    g.add((submission_node, KG_SDM.paper_year, paper_year_lit))
                            
    # adding the keywords
    keyword_node = URIRef(f"http://kg_sdm.org/{keyword}")
    g.add((submission_node, KG_SDM.related_to, keyword_node))

    # adding the paper type
    paper_node = URIRef(f"http://kg_sdm.org/{URLparse(paper_type)}")
    g.add((submission_node, KG_SDM.of_type, paper_node))

# %%
# save_rdf_file(g,'submission_links','ttl')

# %% [markdown]
# ### b. DecisionProcess
# Creating the reviewers, their votes and connecting them with the submission

# %%
reviewProcess = articles_publishedin.drop_duplicates(subset=['title'])
reviewProcess.head()
# Out:
#                                                title  year       type  \
# 0  Self-assessment of Proficiency of Intelligent ...  2001  FullPaper
# 2  Moderating operator influence in human-swarm s...  2018       Demo
# 3  Cooperating in long-term relationships with ti...  2022      Short
# 4  Information design in crowdfunding under thres...  2006      Short
# 7  Intent-based robotic path-replanning: When to ...  2006  FullPaper
#
#     keyword accepted    person_name  \
# 0     Graph     True      Gautam A.
# 2  Database     True  Crandall J.W.
# 3        ML     True  Crandall J.W.
# 4       NLP    False  Crandall J.W.
# 7        ML     True  Goodrich M.A.
#
#                                          school_name
# 0  Computer Science Department, Brigham Young Uni...
# 2  Computer Science Department, Brigham Young Uni...
# 3  Computer Science Department, Brigham Young Uni...
# 4  Computer Science Department, Brigham Young Uni...
# 7  Computer Science Department, Brigham Young Uni...

# %%
reviews = []
comments = []
rejacc = []

for i in range(len(reviewProcess)):
    # create N reviewers and comments
    N = random.randint(2,4)
    # assign N reviewers (get a random sample)
    rev_list = list(reviewers.sample(N)['person_name'])
    # for every reviewer get 
    acc = [random.random()>0.5 for i in range(N)]
    com_list = []
    for j in range(N):
        # generating a random comment
        comment = ''.join((random.choice('abcdefghijklmnopqrstuvwxyz') for i in range(5)))
        com_list.append(comment)
    reviews.append(rev_list)
    comments.append(com_list)
    rejacc.append(acc)
    
reviewProcess['reviewer_name'] = reviews
reviewProcess['comment'] = comments
reviewProcess['decision'] = rejacc

# %% [markdown]
# * As you may have noticed, in DecisionProcess we are randomly assigning the accepted/rejected decision for every reviewer, but we have manually created the accepted/rejected submission in the Submission node.
#
# * The reason why we did this is because it is more complicated to randomly generate the decisions and then connect with the Submisison node. And also because of the fact that it is artificial data and we won't need to query the accepted/rejected decision.
#
# * With the way we did the graph, every article that was accepted can be found using a publication.

# %%
reviewProcess.head()
# Out:
#                                                title  year       type  \
# 0  Self-assessment of Proficiency of Intelligent ...  2019  FullPaper
# 2  Moderating operator influence in human-swarm s...  2020     Poster
# 3  Cooperating in long-term relationships with ti...  2000      Short
# 4  Information design in crowdfunding under thres...  2007     Poster
# 7  Intent-based robotic path-replanning: When to ...  2016      Short
#
#     keyword accepted    person_name  \
# 0  Database     True      Gautam A.
# 2        ML     True  Crandall J.W.
# 3        ML     True  Crandall J.W.
# 4     Graph    False  Crandall J.W.
# 7  Database     True  Goodrich M.A.
#
#                                          school_name  \
# 0  Computer Science Department, Brigham Young Uni...
# 2  Computer Science Department, Brigham Young Uni...
# 3  Computer Science Department, Brigham Young Uni...
# 4  Computer Science Department, Brigham Young Uni...
# 7  Computer Science Department, Brigham Young Uni...
#
#                                        reviewer_name  \
# 0                [Page L., Poornejad N., Terry J.S.]
# 2             [Anderson C.M., Harper C., Galtier M.]
# 3  [Roxanne Hiltz S., Hargis B.H., Codling J.R., ...
# 4      [Behounek M., Song R., Knight M.M., Bowen L.]
# 7      [Slezak T.J., Anderson M., Chetty V., Gou Y.]
#
#                         comment                     decision
# 0         [dhpix, nubee, ontpc]         [False, True, False]
# 2         [razcp, woibt, kujdr]          [True, False, True]
# 3  [bulag, roadv, rwufn, wnual]  [False, True, False, False]
# 4  [dlrsu, oexld, bapkp, pflem]   [True, False, False, True]
# 7  [eserr, pjmqb, epocb, dkafh]  [True, False, False, False]

# %%
# because we were storing the comments and decisions and reviewers in an array
# we will use the explode function to have each reviewer connected to the paper
reviewProcess.apply(pd.Series.explode)
# Out:
#                                                   title  year       type  \
# 0     Self-assessment of Proficiency of Intelligent ...  2019  FullPaper
# 0     Self-assessment of Proficiency of Intelligent ...  2019  FullPaper
# 0     Self-assessment of Proficiency of Intelligent ...  2019  FullPaper
# 2     Moderating operator influence in human-swarm s...  2020     Poster
# 2     Moderating operator influence in human-swarm s...  2020     Poster
# ...                                                 ...   ...        ...
# 2816  Semi-empirical model for fire spread in chamis...  2010      Short
# 2816  Semi-empirical model for fire spread in chamis...  2010      Short
# 2840  Ash deposition during advanced oxy-coal combus...  2007     Poster
# 2840  Ash deposition during advanced oxy-coal combus...  2007     Poster
# 2840  Ash deposition during advanced oxy-coal combus...  2007     Poster
#
#        keyword accepted    person_name  \
# 0     Database     True      Gautam A.
# 0     Database     True      Gautam A.
# 0     Database     True      Gautam A.
# 2           ML     True  Crandall J.W.
# 2           ML     True  Crandall J.W.
# ...        ...      ...            ...
# 2816     Graph    False  Fletcher M.E.
# 2816     Graph    False  Fletcher M.E.
# 2840        ML    False        Wang Y.
# 2840        ML    False        Wang Y.
# 2840        ML    False        Wang Y.
#
#                                             school_name  reviewer_name  \
# 0     Computer Science Department, Brigham Young Uni...        Page L.
# 0     Computer Science Department, Brigham Young Uni...   Poornejad N.
# 0     Computer Science Department, Brigham Young Uni...     Terry J.S.
# 2     Computer Science Department, Brigham Young Uni...  Anderson C.M.
# 2     Computer Science Department, Brigham Young Uni...      Harper C.
# ...                                                 ...            ...
# 2816  Department of Chemical Engineering, Brigham Yo...     Stewart E.
# 2816  Department of Chemical Engineering, Brigham Yo...  Allender E.J.
# 2840  Department of Chemical Engineering, University...    Thomas J.J.
# 2840  Department of Chemical Engineering, University...       Adams D.
# 2840  Department of Chemical Engineering, University...   Wheeler D.R.
#
#      comment decision
# 0      dhpix    False
# 0      nubee     True
# 0      ontpc    False
# 2      razcp     True
# 2      woibt    False
# ...      ...      ...
# 2816   vpwcg    False
# 2816   xfpgk     True
# 2840   huxsn     True
# 2840   ygmwi     True
# 2840   ihzyf    False
#
# [2491 rows x 10 columns]

# %%
for _, article_name, year, _, _, _, _, _, reviewer_name, comment, accepted in reviewProcess.itertuples():
    # get the submission node
    submission_node = URIRef(f"http://kg_sdm.org/Submission/{URLparse(article_title)}")

    # create the reviewProcess node
    review_process = URIRef(f"http://kg_sdm.org/DecisionProcess/{URLparse(author_name+'_'+article_name)}")
    g.add((review_process, RDF.type, KG_SDM.DecisionProcess))
    
    # connect submission and review process
    g.add((submission_node, KG_SDM.goes_through, review_process))
    
    # get the reviewer node
    reviewer_node = URIRef(f"http://kg_sdm.org/Person/{URLparse(author_name)}")
    g.add((reviewer_node, KG_SDM.participates_in, review_process))
    
    # add the literals
    comment_lit = Literal(str(comment))    
    decision_lit = Literal(bool(accepted))
    g.add((review_process, KG_SDM.comment, comment_lit))
    g.add((review_process, KG_SDM.decision, decision_lit))

# %% [markdown]
# ## 3. Venues
# Loading the Venue file which contains journal and conferences and assigning them

# %% [markdown]
# ### a. Adding Conferences and Journals

# %%
publications = pd.read_csv('data_kg_sdm/publications.csv')
publications.head()
# Out:
#    ID                                               name              Type
# 0   1      Advances in Intelligent Systems and Computing  Conference Paper
# 1   2            Lecture Notes in Electrical Engineering  Conference Paper
# 2   3                   Journal of Hydraulic Engineering           Journal
# 3   4  Journal of Computing and Information Science i...           Journal
# 4   5                         Telematics and Informatics  Conference Paper

# %%
journals = publications[publications['Type']=='Journal']
journals.head()
# Out:
#     ID                                               name     Type
# 2    3                   Journal of Hydraulic Engineering  Journal
# 3    4  Journal of Computing and Information Science i...  Journal
# 8    9  International Journal of Electrical Power and ...  Journal
# 10  11                      Journal of Cleaner Production  Journal
# 11  12                 Journal of Manufacturing Processes  Journal

# %%
conferences = publications[publications['Type']!='Journal']
conferences.head()
# Out:
#    ID                                           name              Type
# 0   1  Advances in Intelligent Systems and Computing  Conference Paper
# 1   2        Lecture Notes in Electrical Engineering  Conference Paper
# 4   5                     Telematics and Informatics  Conference Paper
# 5   6                Electric Power Systems Research  Conference Paper
# 6   7                       Optical Fiber Technology  Conference Paper

# %%
# from conferences we split them in 60% worshops and 40% symposiums 
total = len(conferences)
workshops = conferences.iloc[:int(0.4*total):]
symposium = conferences.iloc[int(0.4*total):]

# %%
venue_type_list = [journals,workshops,symposium]
venue_sub_type_ls = ["Journal","Workshop","Symposium"]


for i,venue_tp in enumerate(venue_type_list):
    print(venue_sub_type_ls[i])
    venue_type = venue_sub_type_ls[i]
    venue_sub_type = URIRef(f"http://kg_sdm.org/{venue_type}")
    
    for index,row in venue_tp.iterrows():
        confname = row['name']
        
        # parsing conference
        conf_title = URLparse(confname)
        conf_node = URIRef(f"http://kg_sdm.org/Venue/{conf_title}")
        venue_lit = Literal(str(conf_title))

        # add subclass type
        g.add((conf_node, RDF.type, venue_sub_type))
        # add name of venue
        g.add((conf_node, KG_SDM.venue_title, venue_lit))
# Out:
# Journal
# Workshop
# Symposium

# %%
# save_rdf_file(g,'Venue','ttl')

# %% [markdown]
# ### b. Adding submissions submitted in Venues

# %%
# read the articles
articles = pd.read_csv('data_kg_sdm/articles.csv')
articles.head()
# Out:
#    ID                                              title     volume  \
# 0   1  Self-assessment of Proficiency of Intelligent ...  1210 AISC
# 1   2  Bridging theory to practice: Feedforward and c...   695 LNEE
# 2   3  Development of sediment management guidelines ...        146
# 3   4  Structural design space exploration using prin...         20
# 4   5  Religion-focused dating apps: A Q methodology ...         55
#
#                                   DOI
# 0        10.1007/978-3-030-51758-8_15
# 1         10.1007/978-3-030-58653-9_3
# 2  10.1061/(ASCE)HY.1943-7900.0001822
# 3                   10.1115/1.4047428
# 4          10.1016/j.tele.2020.101448

# %%
# read all the Venues
publications = pd.read_csv('data_kg_sdm/publications.csv')
publications
# Out:
#       ID                                               name              Type
# 0      1      Advances in Intelligent Systems and Computing  Conference Paper
# 1      2            Lecture Notes in Electrical Engineering  Conference Paper
# 2      3                   Journal of Hydraulic Engineering           Journal
# 3      4  Journal of Computing and Information Science i...           Journal
# 4      5                         Telematics and Informatics  Conference Paper
# ..   ...                                                ...               ...
# 399  400                          CAD Computer Aided Design  Conference Paper
# 400  401  International Symposium on Advances in Computa...  Conference Paper
# 401  402  AIAA SPACE and Astronautics Forum and Expositi...  Conference Paper
# 402  403    IEEE Transactions on Control of Network Systems  Conference Paper
# 403  404                 Innovations in Dryland Agriculture  Conference Paper
#
# [404 rows x 3 columns]

# %%
# load article venue merge link
article_publisher_link = pd.read_csv('data_kg_sdm/article_published_by.csv')
article_publisher_link
# Out:
#      article_ID  publisher_ID  year
# 0             1           198  2020
# 1             2           389  2020
# 2             3           216  2020
# 3             4            21  2018
# 4             5           133  2018
# ..          ...           ...   ...
# 875         876           360  2017
# 876         877           229  2015
# 877         878           205  2015
# 878         879            95  2016
# 879         880           394  2016
#
# [880 rows x 3 columns]

# %%
# merge article submitted to Venue
article_pub = pd.merge(articles, article_publisher_link, left_on='ID', right_on='article_ID')
articles_publishedin = pd.merge(article_pub, publications, left_on='publisher_ID', right_on='ID',how='left')
articles_publishedin
# Out:
#      ID_x                                              title     volume  \
# 0       1  Self-assessment of Proficiency of Intelligent ...  1210 AISC
# 1       2  Bridging theory to practice: Feedforward and c...   695 LNEE
# 2       3  Development of sediment management guidelines ...        146
# 3       4  Structural design space exploration using prin...         20
# 4       5  Religion-focused dating apps: A Q methodology ...         55
# ..    ...                                                ...        ...
# 875   876  Formability of magnesium alloy AZ31B from room...    Part F8
# 876   877  A summary of data-aided equalizer experiments ...        NaN
# 877   878  Joining Dissimilar Material Using Friction Sti...        NaN
# 878   879  A minimal realization technique for the dynami...          4
# 879   880               Dryland agriculture in north america        NaN
#
#                                     DOI  article_ID  publisher_ID  year  ID_y  \
# 0          10.1007/978-3-030-51758-8_15           1           198  2020   198
# 1           10.1007/978-3-030-58653-9_3           2           389  2020   389
# 2    10.1061/(ASCE)HY.1943-7900.0001822           3           216  2020   216
# 3                     10.1115/1.4047428           4            21  2018    21
# 4            10.1016/j.tele.2020.101448           5           133  2018   133
# ..                                  ...         ...           ...   ...   ...
# 875        10.1007/978-3-319-52392-7_91         876           360  2017   360
# 876                                 NaN         877           229  2015   229
# 877        10.1007/978-3-319-52383-5_16         878           205  2015   205
# 878           10.1109/TCNS.2015.2498468         879            95  2016    95
# 879        10.1007/978-3-319-47928-6_15         880           394  2016   394
#
#                                                   name              Type
# 0    International Conference on Transportation and...  Conference Paper
# 1                     AAAI Workshop - Technical Report  Conference Paper
# 2                            Advances in Heat Transfer  Conference Paper
# 3    Proceedings - 2020 IEEE 21st International Con...  Conference Paper
# 4                 IEEE Radiation Effects Data Workshop  Conference Paper
# ..                                                 ...               ...
# 875  Proceedings - 2017 IEEE 17th International Con...  Conference Paper
# 876                                   Science Robotics  Conference Paper
# 877         Journal of Guidance, Control, and Dynamics           Journal
# 878                   Geotechnical Special Publication  Conference Paper
# 879  Polyploidy and Hybridization for Crop Improvement  Conference Paper
#
# [880 rows x 10 columns]

# %%
# iterating over above combined dataframe and loading the submission submitted_to venues
for index,row in articles_publishedin.iterrows():
    year = row['year']
    year_literal = Literal(int(year))
    submissiontitle = row['title']
    confname = row['name']
    
    # parsing conference
    conf_title = URLparse(confname)
    conf_node = URIRef(f"http://kg_sdm.org/Venue/{conf_title}")

    # parsing submission
    sub_title = URLparse(submissiontitle)
    sub_node = URIRef(f"http://kg_sdm.org/Submission/{sub_title}")
    
    # connect conference and submission
    g.add((sub_node,KG_SDM.submitted_to,conf_node))

# %% [markdown]
# ### c. Adding Submissions in Publication

# %%
articles = pd.read_csv('data_kg_sdm/articles.csv')
articles['accepted'] = ""
articles['accepted'].loc[:500] = True
articles['accepted'].loc[500:] = False
articles.head()
# Out:
#    ID                                              title     volume  \
# 0   1  Self-assessment of Proficiency of Intelligent ...  1210 AISC
# 1   2  Bridging theory to practice: Feedforward and c...   695 LNEE
# 2   3  Development of sediment management guidelines ...        146
# 3   4  Structural design space exploration using prin...         20
# 4   5  Religion-focused dating apps: A Q methodology ...         55
#
#                                   DOI accepted
# 0        10.1007/978-3-030-51758-8_15     True
# 1         10.1007/978-3-030-58653-9_3     True
# 2  10.1061/(ASCE)HY.1943-7900.0001822     True
# 3                   10.1115/1.4047428     True
# 4          10.1016/j.tele.2020.101448     True

# %%
# load article venue merge link
article_publisher_link = pd.read_csv('data_kg_sdm/article_published_by.csv')
article_publisher_link
# Out:
#      article_ID  publisher_ID  year
# 0             1           198  2020
# 1             2           389  2020
# 2             3           216  2020
# 3             4            21  2018
# 4             5           133  2018
# ..          ...           ...   ...
# 875         876           360  2017
# 876         877           229  2015
# 877         878           205  2015
# 878         879            95  2016
# 879         880           394  2016
#
# [880 rows x 3 columns]

# %%
articles_publishedin = pd.merge(articles, article_publisher_link, left_on='ID', right_on='article_ID')
articles_publishedin
# Out:
#       ID                                              title     volume  \
# 0      1  Self-assessment of Proficiency of Intelligent ...  1210 AISC
# 1      2  Bridging theory to practice: Feedforward and c...   695 LNEE
# 2      3  Development of sediment management guidelines ...        146
# 3      4  Structural design space exploration using prin...         20
# 4      5  Religion-focused dating apps: A Q methodology ...         55
# ..   ...                                                ...        ...
# 875  876  Formability of magnesium alloy AZ31B from room...    Part F8
# 876  877  A summary of data-aided equalizer experiments ...        NaN
# 877  878  Joining Dissimilar Material Using Friction Sti...        NaN
# 878  879  A minimal realization technique for the dynami...          4
# 879  880               Dryland agriculture in north america        NaN
#
#                                     DOI accepted  article_ID  publisher_ID  \
# 0          10.1007/978-3-030-51758-8_15     True           1           198
# 1           10.1007/978-3-030-58653-9_3     True           2           389
# 2    10.1061/(ASCE)HY.1943-7900.0001822     True           3           216
# 3                     10.1115/1.4047428     True           4            21
# 4            10.1016/j.tele.2020.101448     True           5           133
# ..                                  ...      ...         ...           ...
# 875        10.1007/978-3-319-52392-7_91    False         876           360
# 876                                 NaN    False         877           229
# 877        10.1007/978-3-319-52383-5_16    False         878           205
# 878           10.1109/TCNS.2015.2498468    False         879            95
# 879        10.1007/978-3-319-47928-6_15    False         880           394
#
#      year
# 0    2020
# 1    2020
# 2    2020
# 3    2018
# 4    2018
# ..    ...
# 875  2017
# 876  2015
# 877  2015
# 878  2016
# 879  2016
#
# [880 rows x 8 columns]

# %% [markdown]
# #### I. Adding Journal publications in Volume

# %%
# Get all the journals  
articles_publishedin_journal = pd.merge(articles_publishedin, journals, left_on='publisher_ID', right_on='ID')
articles_publishedin_journal
# Out:
#      ID_x                                              title     volume  \
# 0      14  In-situ strain measurement of ballistic fabric...         59
# 1     487  Understanding engineering and technology stude...  2018-June
# 2      17  High-Speed Acoustic Impact-Echo Sounding of Co...         39
# 3      31  An iterative pose estimation algorithm based o...          7
# 4      34   Developable mechanisms on right conical surfaces        149
# ..    ...                                                ...        ...
# 211   761  Ground-based 3D radar imaging of trees using a...          6
# 212   771  Theoretical estimates of maximum fields in sup...         30
# 213   780  MMI waveguide based multispectral detection of...        NaN
# 214   816  Two-phase flow pressure drop in superhydrophob...        110
# 215   862  Geofoam inclusions for reducing passive force ...        NaN
#
#                                           DOI accepted  article_ID  \
# 0                 10.1016/j.yofte.2020.102334     True          14
# 1                                         NaN     True         487
# 2                  10.1007/s10921-020-00695-0     True          17
# 3                    10.1109/JAS.2020.1003222     True          31
# 4        10.1016/j.mechmachtheory.2020.103813     True          34
# ..                                        ...      ...         ...
# 211                10.3390/electronics6010011    False         761
# 212             10.1088/1361-6668/30/3/033002    False         771
# 213                10.1109/IPCon.2016.7831137    False         780
# 214  10.1016/j.ijheatmasstransfer.2017.03.055    False         816
# 215                 10.1061/9780784480465.007    False         862
#
#      publisher_ID  year  ID_y  \
# 0             112  2020   112
# 1             112  2016   112
# 2             145  2018   145
# 3             351  2019   351
# 4             287  2019   287
# ..            ...   ...   ...
# 211           355  2015   355
# 212            74  2016    74
# 213             4  2015     4
# 214            65  2015    65
# 215           226  2016   226
#
#                                                   name     Type
# 0    International Journal of Modelling and Simulation  Journal
# 1    International Journal of Modelling and Simulation  Journal
# 2         Journal of Mechanics in Medicine and Biology  Journal
# 3     International Journal of Industrial Organization  Journal
# 4    Journal of Homeland Security and Emergency Man...  Journal
# ..                                                 ...      ...
# 211       Journal of Mechanical Science and Technology  Journal
# 212                       Journal of Nanobiotechnology  Journal
# 213  Journal of Computing and Information Science i...  Journal
# 214          Journal of Microelectromechanical Systems  Journal
# 215  Turkish Journal of Electrical Engineering and ...  Journal
#
# [216 rows x 11 columns]

# %%
# Adding the journals in volumes only which are accepted (where decision = True )
for index,row in articles_publishedin_journal.iterrows():
    year = row['year']
    year_literal = Literal(int(year))
    submissiontitle = row['title']
    confname = row['name']
    decision = row['accepted']
    
    # parsing conference
    conf_title = URLparse(confname)
    conf_node = URIRef(f"http://kg_sdm.org/Venue/{conf_title}")

    
    # parsing submission
    sub_title = URLparse(submissiontitle)
    sub_node = URIRef(f"http://kg_sdm.org/Submission/{sub_title}")

    
    # parsing for publication
    # assuming only half of the articles got accepted
    if decision:
        Pub_title = conf_title+'_volume_'+str(random.randint(1, 5))
        Pub_title_lit = Literal(str(Pub_title))
        
        pub_node = URIRef(f"http://kg_sdm.org/Publication/{Pub_title}")
        g.add((pub_node, RDF.type, KG_SDM.Volume))
        g.add((sub_node,KG_SDM.published_in,pub_node))
        g.add((pub_node, KG_SDM.publication_title,Pub_title_lit))
        g.add((pub_node, KG_SDM.publication_year,year_literal))

# %% [markdown]
# #### II. Adding Conference publications in Proceddings

# %%
# get all the conferences
conferences = workshops.append(symposium)
conferences
# Out:
#       ID                                               name              Type
# 0      1      Advances in Intelligent Systems and Computing  Conference Paper
# 1      2            Lecture Notes in Electrical Engineering  Conference Paper
# 4      5                         Telematics and Informatics  Conference Paper
# 5      6                    Electric Power Systems Research  Conference Paper
# 6      7                           Optical Fiber Technology  Conference Paper
# ..   ...                                                ...               ...
# 399  400                          CAD Computer Aided Design  Conference Paper
# 400  401  International Symposium on Advances in Computa...  Conference Paper
# 401  402  AIAA SPACE and Astronautics Forum and Expositi...  Conference Paper
# 402  403    IEEE Transactions on Control of Network Systems  Conference Paper
# 403  404                 Innovations in Dryland Agriculture  Conference Paper
#
# [304 rows x 3 columns]

# %%
articles_publishedin_conf = pd.merge(articles_publishedin, conferences, left_on='publisher_ID', right_on='ID')
articles_publishedin_conf
# Out:
#      ID_x                                              title     volume  \
# 0       1  Self-assessment of Proficiency of Intelligent ...  1210 AISC
# 1      95  Using Cyclic Quadrilaterals to Design Cylindri...         83
# 2     474  Design and characterization of a package-less ...         17
# 3     651           Human factors in mission control centers        NaN
# 4       2  Bridging theory to practice: Feedforward and c...   695 LNEE
# ..    ...                                                ...        ...
# 659   811  Optimization of origami-based tubes for lightw...    5B-2017
# 660   821                                           Foreword        NaN
# 661   845  Modeling the coanda effect with FDS and STARCC...        NaN
# 662   849  Split-vertex technique for thickness-accommoda...    5B-2017
# 663   880               Dryland agriculture in north america        NaN
#
#                                     DOI accepted  article_ID  publisher_ID  \
# 0          10.1007/978-3-030-51758-8_15     True           1           198
# 1          10.1007/978-3-030-43929-3_14     True          95           198
# 2             10.1117/1.JMM.17.3.034501     True         474           198
# 3    10.1016/B978-0-08-101869-9.00013-3    False         651           198
# 4           10.1007/978-3-030-58653-9_3     True           2           389
# ..                                  ...      ...         ...           ...
# 659              10.1115/DETC2017-67274    False         811           298
# 660                                 NaN    False         821           122
# 661                                 NaN    False         845           153
# 662              10.1115/DETC2017-68018    False         849           128
# 663        10.1007/978-3-319-47928-6_15    False         880           394
#
#      year  ID_y                                               name  \
# 0    2020   198  International Conference on Transportation and...
# 1    2018   198  International Conference on Transportation and...
# 2    2017   198  International Conference on Transportation and...
# 3    2018   198  International Conference on Transportation and...
# 4    2020   389                   AAAI Workshop - Technical Report
# ..    ...   ...                                                ...
# 659  2015   298                              ACS Synthetic Biology
# 660  2015   122  2019 IEEE Photonics Conference, IPC 2019 - Pro...
# 661  2016   153  Composites Part A: Applied Science and Manufac...
# 662  2015   128                 Sensors and Actuators, B: Chemical
# 663  2016   394  Polyploidy and Hybridization for Crop Improvement
#
#                  Type
# 0    Conference Paper
# 1    Conference Paper
# 2    Conference Paper
# 3    Conference Paper
# 4    Conference Paper
# ..                ...
# 659  Conference Paper
# 660  Conference Paper
# 661  Conference Paper
# 662  Conference Paper
# 663  Conference Paper
#
# [664 rows x 11 columns]

# %%
# Adding the conference in Proceddings only which are accepted (where decision = True )
for index,row in articles_publishedin_conf.iterrows():
    year = row['year']
    year_literal = Literal(int(year))
    submissiontitle = row['title']
    confname = row['name']
    decision = row['accepted']
    
    # parsing conference
    conf_title = URLparse(confname)
    conf_node = URIRef(f"http://kg_sdm.org/Venue/{conf_title}")

    
    # parsing submission
    sub_title = URLparse(submissiontitle)
    sub_node = URIRef(f"http://kg_sdm.org/Submission/{sub_title}")

    
    # parsing for publication
    # assuming only half of the articles got accepted
    if decision:
        Pub_title = conf_title+'_proceddings'
        Pub_title_lit = Literal(str(Pub_title))
        
        pub_node = URIRef(f"http://kg_sdm.org/Publication/{Pub_title}")
        g.add((pub_node, RDF.type, KG_SDM.Proceddings))
        g.add((sub_node,KG_SDM.published_in,pub_node))
        g.add((pub_node, KG_SDM.publication_title,Pub_title_lit))
        g.add((pub_node, KG_SDM.publication_year,year_literal))

# %% [markdown]
# ### d. Adding handlers
#
# * conferences are handled by chair
# * Journals are handled by editor

# %%
# As defined in person
chair.head()
# Out:
#       ID_x                                        school_name    author_ID  \
# 1737   989  Department of Physics and Astronomy, Brigham Y...  57204435650
# 1738   989  Department of Physics and Astronomy, Brigham Y...  57204415715
# 1739   991  Department of Civil and Environmental Engineer...  57193610705
# 1740   994  Aerion Technologies Corporation, Mechanical En...  15833172400
# 1741   996   New Product Development, Intuitive Surgical I...  55916540700
#
#       org_ID         ID_y    person_name
# 1737     989  57204435650    Laughlin E.
# 1738     989  57204415715        Howe L.
# 1739     991  57193610705      Talbot M.
# 1740     994  15833172400  Rajnarayan D.
# 1741     996  55916540700      Grames C.

# %%
# editor as defined in journal
editor.head()
# Out:
#       ID_x                                        school_name    author_ID  \
# 1954  1205  Dipartimento di Fisica, Università degli Studi...   6701695863
# 1955  1206   INFN Milano, via G. Celoria, 16, Milano, 2013...  37098602100
# 1956  1206   INFN Milano, via G. Celoria, 16, Milano, 2013...   7006631262
# 1957  1207   NSF Center for High Performance Reconfigurabl...  56404157200
# 1958  1208   Brookhaven National Laboratory, UptonNY, Unit...  56424241200
#
#       org_ID         ID_y   person_name
# 1954    1205   6701695863   Citterio M.
# 1955    1206  37098602100   Camplani A.
# 1956    1206   7006631262  Lazzaroni M.
# 1957    1207  56404157200      Takai H.
# 1958    1208  56424241200       Chen H.

# %%
journals['editors'] = editor.iloc[:len(journals)]['person_name'].values
journals.head()
# Out:
#     ID                                               name     Type  \
# 2    3                   Journal of Hydraulic Engineering  Journal
# 3    4  Journal of Computing and Information Science i...  Journal
# 8    9  International Journal of Electrical Power and ...  Journal
# 10  11                      Journal of Cleaner Production  Journal
# 11  12                 Journal of Manufacturing Processes  Journal
#
#          editors
# 2    Citterio M.
# 3    Camplani A.
# 8   Lazzaroni M.
# 10      Takai H.
# 11       Chen H.

# %%
# getting list of chairs
chair_names = list(chair['person_name'].values)
# since we do not have chair in our data, generating random peopels from chair to handle the conferences
conf_chairs = [chair_names[random.randint(0,len(chair_names)-1)]  for i in range(len(conferences))]
# saving conference handlers
conferences['chair'] = conf_chairs
conferences
# Out:
#       ID                                               name              Type  \
# 0      1      Advances in Intelligent Systems and Computing  Conference Paper
# 1      2            Lecture Notes in Electrical Engineering  Conference Paper
# 4      5                         Telematics and Informatics  Conference Paper
# 5      6                    Electric Power Systems Research  Conference Paper
# 6      7                           Optical Fiber Technology  Conference Paper
# ..   ...                                                ...               ...
# 399  400                          CAD Computer Aided Design  Conference Paper
# 400  401  International Symposium on Advances in Computa...  Conference Paper
# 401  402  AIAA SPACE and Astronautics Forum and Expositi...  Conference Paper
# 402  403    IEEE Transactions on Control of Network Systems  Conference Paper
# 403  404                 Innovations in Dryland Agriculture  Conference Paper
#
#                     chair
# 0                Birch S.
# 1    Santos-Villalobos H.
# 4       Abraham Martin R.
# 5             Laughlin E.
# 6                  Han J.
# ..                    ...
# 399          Gladstone R.
# 400         Tamashasky B.
# 401            Field D.P.
# 402            Morales C.
# 403         Lavadiya D.N.
#
# [304 rows x 4 columns]

# %%
# adding the chair handlers
for index,row in conferences.iterrows():
    authorname = row['chair']
    confname = row['name']

    # parsing conference
    conf_title = URLparse(confname)
    conf_node = URIRef(f"http://kg_sdm.org/venue/{conf_title}")
    venue_lit = Literal(str(conf_title))

    # parsing authors
    per_title = URLparse(authorname)
    per_node = URIRef(f"http://kg_sdm.org/Person/{per_title}")


    g.add((per_node, KG_SDM.handles, conf_node))

# %%
# adding the editor handlers
for index,row in journals.iterrows():
    authorname = row['editors']
    confname = row['name']

    # parsing conference
    conf_title = URLparse(confname)
    conf_node = URIRef(f"http://kg_sdm.org/venue/{conf_title}")
    venue_lit = Literal(str(conf_title))

    # parsing authors
    per_title = URLparse(authorname)
    per_node = URIRef(f"http://kg_sdm.org/Person/{per_title}")


    g.add((per_node, KG_SDM.handles, conf_node))

# %% [markdown]
# ## 4. Saving the Graph

# %%
save_rdf_file(g,"abox",rdf_format='ttl')
